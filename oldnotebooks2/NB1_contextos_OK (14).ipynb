# %% [markdown]
# # NB1 — Aquisição, Validação e Pré-processamento de Contextos de Crise
#
# **Pipeline de Predição de Crises Epilépticas a partir de EEG**
#
# Este notebook:
# 1. Define os contextos de crise válidos para os 24 pacientes selecionados
# 2. Verifica integridade de cada contexto
# 3. Aplica filtros (passa-alta 0.5Hz, passa-baixa 40Hz, notch 50/60Hz) e reamostra para 256Hz
# 4. Salva os sinais pré-processados em `.npz` por contexto
# 5. Exibe tabela detalhada de todos os pacientes e contextos
# 6. Plota o EEG de cada contexto válido
# 7. Exporta o mapa de contextos em JSON para o NB2
#
# **Parâmetros da lógica de contexto:**
# - `GUARD = 30 min` — zona proibida pós-crise e margem antes do pré-ictal
# - `MAX_PRE = 40 min` — janela pré-ictal máxima
# - `MIN_INTER = 40 min` — interictal mínimo (simétrico ao pré-ictal)
# - `MIN_CONTEXTS = 2` — contextos válidos mínimos para o paciente ser selecionável
#
# **Estrutura do contexto:** `[interictal 40min][guard 30min][pré-ictal 40min][CRISE][guard 30min]`

# %% [markdown]
# ## 1. Imports e parâmetros

# %%
import os, re, json, warnings
from pathlib import Path
from collections import defaultdict
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

warnings.filterwarnings('ignore', category=RuntimeWarning)

try:
    import mne
    mne.set_log_level('ERROR')
    HAS_MNE = True
except ImportError:
    HAS_MNE = False
    print('MNE nao instalado — instale com: pip install mne')

# ── Diretorios ────────────────────────────────────────────────────────────────
ROOT            = Path('data')
CHBMIT_DIR      = ROOT / 'chb-mit'
SIENA_DIR       = ROOT / 'siena'
SEIZEIT_DIR     = ROOT / 'seizeit2'
MENDELEY_DIR    = ROOT / 'mendeley'
SIGNAL_DIR      = ROOT / 'signals'    # .npz dos contextos pre-processados
SEIZEIT_SESSION = 'ses-01'
SIGNAL_DIR.mkdir(parents=True, exist_ok=True)

# ── Parâmetros do contexto de crise ──────────────────────────────────────────
GUARD_S     = 30 * 60   # 30 min
MAX_PRE_S   = 40 * 60   # 40 min
MIN_INTER_S = 40 * 60   # 40 min
MIN_CONTEXTS = 2

# ── Parâmetros de pré-processamento ──────────────────────────────────────────
TARGET_SFREQ = 256.0    # Hz — reamostragem alvo
F_HIGHPASS   = 0.5      # Hz — passa-alta (remove drift DC)
F_LOWPASS    = 40.0     # Hz — passa-baixa (remove ruido alta frequencia)
NOTCH_FREQS  = [50, 60] # Hz — notch (rede eletrica Europa + EUA)

# ── Seleção automática de pacientes ──────────────────────────────────────────
# Os pacientes são descobertos automaticamente em disco e rankeados por número
# de contextos válidos. São selecionados TODOS com >= MIN_CONTEXTS contextos.
# Não há lista manual — a seleção é determinada pelos parâmetros e pelos dados.
#
# N_SELECT_PER_DS: None = todos os elegíveis; int = top-N por dataset.
# Recomendado: None (seleção data-driven, sem viés de curadoria manual).
N_SELECT_PER_DS = None   # None = todos com >= MIN_CONTEXTS válidos

print('Parâmetros carregados.')
# Out:
# Parâmetros carregados.

# %% [markdown]
# ## 2. Ground truth de anotações (Siena e Mendeley)

# %%
# ── Horas de crise do Siena (relógio HH:MM:SS) ───────────────────────────────
# onset_s é calculado automaticamente pela função siena_seizures_from_clock()
# que lê o rec_start do header EDF e faz: onset = (sz_clock - rec_start) % 86400
# Nota: PN00-3.edf excluído (delta 61min = gravação inteira, não crise)
#       PN03-1.edf excluído (arquivo truncado — crise fora do range)
#       PN07/PN11: 1 crise apenas → nunca elegíveis (< MIN_CONTEXTS)
SIENA_SEIZURE_CLOCK = {
    'PN00': {
        'pn00-1.edf': [('19:58:36','19:59:46')],
        'pn00-2.edf': [('02:38:37','02:39:31')],
        # pn00-3.edf: IGNORADO — delta=61min, provavelmente intervalo de gravação
        'pn00-4.edf': [('21:08:29','21:09:43')],
        'pn00-5.edf': [('22:37:08','22:38:15')],
    },
    'PN01': {  # já em SIENA_GT; valores calculados = verificados ✓
        'pn01-1.edf': [('21:51:02','21:51:56'), ('07:53:17','07:54:31')],
    },
    'PN03': {
        # pn03-1.edf: EXCLUIDO (arquivo truncado)
        'pn03-2.edf': [('07:13:05','07:15:18')],
    },
    'PN05': {
        'pn05-2.edf': [('08:45:25','08:46:00')],
        'pn05-3.edf': [('07:55:19','07:55:49')],
        'pn05-4.edf': [('07:38:43','07:39:22')],
    },
    'PN06': {
        'pno6-1.edf': [('05:54:25','05:55:29')],  # atenção: PNO6 (O maiúsculo)
        'pno6-2.edf': [('23:39:09','23:40:18')],
        'pn06-3.edf': [('08:10:26','08:11:08')],
        'pno6-4.edf': [('12:55:08','12:56:11')],
        'pn06-5.edf': [('14:44:24','14:45:08')],
    },
    'PN09': {
        'pn09-1.edf': [('16:09:43','16:11:03')],
        'pn09-2.edf': [('17:00:56','17:01:55')],
        'pn09-3.edf': [('16:20:44','16:21:48')],
    },
    'PN10': {
        'pn10-1.edf':     [('07:45:50','07:46:59')],
        'pn10-2.edf':     [('11:40:13','11:41:04')],
        'pn10-3.edf':     [('15:43:53','15:45:02')],
        'pn10-4.5.6.edf': [('12:49:50','12:49:55'),('14:00:25','14:00:44'),('15:18:26','15:19:23')],
        'pn10-7.8.9.edf': [('17:35:13','17:36:01'),('18:20:24','18:20:42'),('20:24:48','20:25:03')],
        'pn10-10.edf':    [('10:58:19','10:58:33')],
    },
    'PN12': {
        'pn12-1.2.edf': [('16:13:23','16:14:26'), ('18:31:01','18:32:09')],
        'pn12-3.edf':   [('08:55:27','08:57:03')],
        'pn12-4.edf':   [('18:42:51','18:43:54')],
    },
    'PN13': {
        'pn13-1.edf': [('10:22:10','10:22:58')],
        'pn13-2.edf': [('08:55:51','08:56:56')],
        'pn13-3.edf': [('14:05:54','14:08:25')],
    },
    'PN14': {
        'pn14-1.edf': [('13:46:00','13:46:27')],
        'pn14-2.edf': [('17:54:52','17:55:04')],
        'pn14-3.edf': [('21:10:05','21:10:46')],
        'pn14-4.edf': [('15:49:33','15:50:56')],
    },
    'PN16': {
        'pn16-1.edf': [('22:45:05','22:47:08')],
        'pn16-2.edf': [('03:16:49','03:18:36')],
    },
    'PN17': {
        'pn17-1.edf': [('22:34:48','22:35:58')],
        'pn17-2.edf': [('16:01:09','16:02:32')],
    },
}

def _hms_to_s(hms_str):
    '''HH:MM:SS ou HH.MM.SS → segundos desde meia-noite.'''
    parts = hms_str.replace('.', ':').split(':')
    return int(parts[0]) * 3600 + int(parts[1]) * 60 + int(parts[2])

def parse_siena_annotation_txt(pat_dir):
    '''Lê Seizures-list-PNXX.txt do Siena sem abrir EDFs.

    Formato PhysioNet (verificado em PN10):
      Seizure n 1:
      File name: PN10-1.edf
      Registration start time: 05.40.05
      Seizure start time: 07.45.50
      Seizure end time: 07.46.59

    Quirks tratados:
      - "1 6.49.25" (typo de espaço) → "16.49.25"
      - "(CLINICAL ONSET)", "opure HH.MM.SS" (texto extra) → ignorado
      - Múltiplas crises no mesmo EDF → lista de (onset_s, offset_s)

    Retorna {edf_name_lower: [(onset_s, offset_s), ...]}
    '''
    pat_dir = Path(pat_dir)
    ann = None
    for pat_glob in ['Seizures-list-*.txt', 'Seizure*list*.txt', '*.txt']:
        txts = sorted(pat_dir.glob(pat_glob))
        if txts: ann = txts[0]; break
    if ann is None:
        return {}

    def _parse_time(t_str):
        t_str = t_str.strip()
        # Remove texto extra: "(CLINICAL ONSET)", "opure HH.MM.SS", etc.
        t_str = re.split(r'[;(]|\bopure\b|\bor\b', t_str, flags=re.I)[0].strip()
        # Fix typo: "1 6.49.25" → "16.49.25"
        t_str = re.sub(r'(\d)\s+(\d)', r'\1\2', t_str)
        # Normaliza separadores (. ou - → :)
        t_str = re.sub(r'[.\-]', ':', t_str)
        m = re.match(r'(\d{1,2}):(\d{2}):(\d{2})', t_str)
        if m:
            return int(m.group(1))*3600 + int(m.group(2))*60 + int(m.group(3))
        return None

    text   = ann.read_text(errors='ignore')
    result = {}  # {edf_lower: [(onset_s, offset_s)]}

    # Divide por bloco de crise ("Seizure n X")
    blocks = re.split(r'Seizure\s+n[°.]?\s*\d+', text, flags=re.IGNORECASE)
    for block in blocks[1:]:
        fname = rec_s = sz_on = sz_off = None
        for ln in block.split('\n'):
            ln = ln.strip()
            m = re.search(r'(?i)file\s+name\s*:\s*(\S+\.edf)', ln)
            if m: fname = m.group(1).lower(); continue
            m = re.search(r'(?i)registration\s+start\s+time\s*:\s*(.+)', ln)
            if m: rec_s = _parse_time(m.group(1)); continue
            m = re.search(r'(?i)seizure\s+start\s+time\s*:\s*(.+)', ln)
            if m: sz_on = _parse_time(m.group(1)); continue
            m = re.search(r'(?i)seizure\s+end\s+time\s*:\s*(.+)', ln)
            if m: sz_off = _parse_time(m.group(1)); continue
        if fname and rec_s is not None and sz_on is not None and sz_off is not None:
            onset_s  = (sz_on  - rec_s + 86400) % 86400
            offset_s = (sz_off - rec_s + 86400) % 86400
            if offset_s < onset_s: offset_s += 86400
            if 0 < offset_s - onset_s < 600:   # crise válida: 0–10min
                result.setdefault(fname, []).append((int(onset_s), int(offset_s)))
    return result


print('parse_siena_annotation_txt() definida (lê anotação sem abrir EDF).')
# Siena: onsets em segundos relativos ao inicio do arquivo
# Calculados como: onset = hms(sz_start) - hms(reg_start); se negativo: += 86400
# PN03-1.edf EXCLUIDO: arquivo truncado (349min em disco, crise em 644min)
SIENA_GT = {
    'PN01': {
        'pn01-1.edf': [(10218, 10272), (46353, 46427)],
    },
    'PN05': {
        'pn05-2.edf': [(7163, 7198)],
        'pn05-3.edf': [(6836, 6866)],
        'pn05-4.edf': [(3608, 3647)],
    },
    'PN09': {
        'pn09-1.edf': [(7249, 7329)],
        'pn09-2.edf': [(7127, 7186)],
        'pn09-3.edf': [(7221, 7285)],
    },
    'PN10': {
        'pn10-1.edf':       [(7545, 7614)],
        'pn10-2.edf':       [(7798, 7849)],
        'pn10-3.edf':       [(7835, 7904)],
        'pn10-4.5.6.edf':   [(2309, 2314), (6544, 6563), (11225, 11282)],
        'pn10-7.8.9.edf':   [(2748, 2796), (5459, 5477), (12923, 12938)],
        'pn10-10.edf':      [(7977, 7991)],
    },
    'PN13': {
        'pn13-1.edf': [(7062, 7110)],
        'pn13-2.edf': [(7249, 7314)],
        'pn13-3.edf': [(7553, 7704)],
    },
    'PN14': {
        'pn14-1.edf': [(7262,  7289)],
        'pn14-2.edf': [(7479,  7491)],
        'pn14-3.edf': [(17540, 17581)],
        'pn14-4.edf': [(5463,  5546)],
    },
    'PN17': {
        'pn17-1.edf': [(8420, 8490)],
        'pn17-2.edf': [(7731, 7814)],
    },
}

MENDELEY_GT = {
    'p10': {
        'p10_record1.edf': [(7199, 7644)],
        'p10_record2.edf': [(7200, 7505)],
    },
    'p13': {
        'p13_record1.edf': [(7196, 7248)],
        'p13_record2.edf': [(3241, 3266), (7196, 7212)],
        'p13_record3.edf': [(7240, 7258)],
        'p13_record4.edf': [(1450, 1480), (6651, 6675)],
    },
    'p15': {
        'p15_record1.edf': [(7158, 7208)],
        'p15_record2.edf': [(7147, 7194)],
        'p15_record3.edf': [(7132, 7145)],
        'p15_record4.edf': [(2431, 2487), (7234, 7254)],
    },
}
print('Ground truth carregado.')
# Out:
# parse_siena_annotation_txt() definida (lê anotação sem abrir EDF).
# Ground truth carregado.

# %% [markdown]
# ## 3. Funções auxiliares

# %%
def fix_siena_filename(filename):
    """Corrige nomes conhecidos do Siena."""
    if filename.lower() == 'pn01.edf':    return 'pn01-1.edf'
    if filename.lower() == 'pn11-.edf':   return 'pn11-1.edf'
    if 'pno6' in filename.lower():        return filename.replace('pno6','PN06').replace('PNO6','PN06')
    return filename

def m(s):
    return round(s / 60, 1) if s is not None else None

def fmt_hms(s):
    if s is None: return '--'
    s = int(round(float(s)))
    return f'{s//3600:02d}:{(s%3600)//60:02d}:{s%60:02d}'

def normalize_fn(f):
    return re.sub(r'-+', '-', f.lower())

def siena_match(fn, gt):
    k = normalize_fn(fn)
    if k in gt: return gt[k]
    parts = k.split('-', 1)
    if len(parts) == 2:
        p, s = parts
        for v in [p.replace('0','o'), p.replace('o','0')]:
            if v+'-'+s in gt: return gt[v+'-'+s]
    return []

def parse_chbmit_summary(path):
    sz_map, free = {}, []
    blocks = open(path, errors='ignore').read().split('File Name:')
    for block in blocks[1:]:
        lines = block.strip().split('\n')
        fname = lines[0].strip()
        n_sz = 0; onsets = []; offsets = []
        for ln in lines:
            if 'Number of Seizures' in ln:
                try: n_sz = int(re.search(r'\d+', ln.split(':',1)[1]).group())
                except: pass
            elif 'Seizure' in ln and 'Start Time' in ln:
                mx = re.search(r'(\d+)', ln.split(':',1)[1])
                if mx: onsets.append(int(mx.group()))
            elif 'Seizure' in ln and 'End Time' in ln:
                mx = re.search(r'(\d+)', ln.split(':',1)[1])
                if mx: offsets.append(int(mx.group()))
        if n_sz > 0:
            sz_map[fname] = [(o,e) for o,e in zip(onsets,offsets) if e>o]
        else:
            free.append(fname)
    return sz_map, free

def get_edf_duration(path):
    if HAS_MNE:
        try:
            raw = mne.io.read_raw_edf(str(path), preload=False, verbose=False)
            d = (raw.n_times - 1) / raw.info['sfreq']
            raw.close()
            return d
        except: pass
    return path.stat().st_size / (256 * 23 * 2)

print('Funções auxiliares definidas.')
# Out:
# Funções auxiliares definidas.

# %% [markdown]
# ## 4. Validadores de contexto

# %%
def validate_dedicated(pat, edf_list):
    '''CHB-MIT / SeizeIT2: interictal de arquivos puros, ponteiro sequencial.
    Criterio: onset >= MAX_PRE_S (40min).
    Pre-ictal verificado contra pos-ictal de crises anteriores no mesmo arquivo.
    '''
    pure_edfs = sorted([e for e in edf_list if e['is_pure']], key=lambda x: x['name'])
    sz_edfs   = sorted([e for e in edf_list if not e['is_pure'] and e['seizures']],
                       key=lambda x: x['name'])
    pool = [{'name': pe['name'], 'path': pe['path'],
             'dur_s': pe['dur_s'], 'used_s': 0.0} for pe in pure_edfs]
    pool_idx = 0
    contexts = []

    for edf in sz_edfs:
        seiz = edf['seizures']
        for i, (on, off) in enumerate(seiz):
            approved = on >= MAX_PRE_S
            motivo = None
            if not approved:
                motivo = f'onset={m(on)}min < MAX_PRE={m(MAX_PRE_S)}min'
            else:
                pre_ini = on - MAX_PRE_S
                for j, (on_o, off_o) in enumerate(seiz):
                    if j == i: continue
                    if pre_ini < off_o and on > on_o:
                        approved = False
                        motivo = f'pre-ictal contem crise #{j+1}'
                        break
                    if off_o < on and pre_ini < off_o + GUARD_S and on > off_o:
                        approved = False
                        motivo = f'pre-ictal colide pos-ictal crise #{j+1}'
                        break

            # calcula pre_max_disp
            prev_limit = max((off_o + GUARD_S for _, off_o in seiz if off_o < on),
                             default=0)
            pre_max_disp = max(0, on - prev_limit)

            if not approved:
                contexts.append({
                    'edf': edf['name'], 'path': edf['path'],
                    'dur_edf': edf['dur_s'], 'sz_idx': i+1,
                    'on_s': on, 'off_s': off, 'n_sz_edf': len(seiz),
                    'approved_pre': False, 'pre_max_disp_s': pre_max_disp,
                    'pre_inicio_s': None, 'pre_fim_s': None,
                    'inter_arquivo': None, 'inter_path': None,
                    'inter_inicio_s': None, 'inter_fim_s': None,
                    'inter_fonte': '--', 'valid': False, 'motivo': motivo,
                })
                continue

            pi = pool_idx
            found = False
            while pi < len(pool):
                p = pool[pi]
                restante = (p['dur_s'] or 999999.0) - p['used_s']  # dur_s=None → trata como arquivo longo
                if restante >= MIN_INTER_S:
                    # CHB-MIT: salva arquivo puro inteiro (tipicamente 60min).
                    # 1 arquivo por contexto — sem compartilhamento para evitar leakage.
                    ini = p['used_s']; fim = p['dur_s'] or 999999.0 or 999999.0
                    p['used_s'] = fim; pool_idx = pi
                    contexts.append({
                        'edf': edf['name'], 'path': edf['path'],
                        'dur_edf': edf['dur_s'], 'sz_idx': i+1,
                        'on_s': on, 'off_s': off, 'n_sz_edf': len(seiz),
                        'approved_pre': True, 'pre_max_disp_s': pre_max_disp,
                        'pre_inicio_s': on - MAX_PRE_S, 'pre_fim_s': on,
                        'inter_arquivo': p['name'], 'inter_path': p['path'],
                        'inter_inicio_s': ini, 'inter_fim_s': fim,
                        'inter_fonte': 'dedicado',
                        'valid': True,
                        'motivo': f'inter dedicado {p["name"]} [{m(ini)}-{m(fim)}min]',
                    })
                    found = True; break
                pi += 1; pool_idx = pi
            if not found:
                contexts.append({
                    'edf': edf['name'], 'path': edf['path'],
                    'dur_edf': edf['dur_s'], 'sz_idx': i+1,
                    'on_s': on, 'off_s': off, 'n_sz_edf': len(seiz),
                    'approved_pre': True, 'pre_max_disp_s': pre_max_disp,
                    'pre_inicio_s': on - MAX_PRE_S, 'pre_fim_s': on,
                    'inter_arquivo': None, 'inter_path': None,
                    'inter_inicio_s': None, 'inter_fim_s': None,
                    'inter_fonte': 'esgotado', 'valid': False,
                    'motivo': 'pool de interictal puro esgotado',
                })
    return contexts

# %%
def validate_intra(pat, edf_list):
    '''Siena / Mendeley: interictal intra-arquivo, 2 passadas + lock.
    Criterio: onset >= MAX_PRE_S + GUARD_S (70min).
    '''
    MIN_ONSET = MAX_PRE_S + GUARD_S
    contexts = []

    for edf in edf_list:
        if edf['is_pure'] or not edf['seizures']:
            continue
        dur  = edf['dur_s']
        seiz = edf['seizures']

        # Passada 1: zonas proibidas de todas as crises
        forbidden = [(max(0, on - MAX_PRE_S - GUARD_S), off + GUARD_S)
                     for on, off in seiz]
        forbidden.sort()
        locked = []

        def free_space(start, end):
            blocks = []; cur = start
            for (a, b) in sorted(forbidden + locked):
                if b <= cur: continue
                if a >= end: break
                if a > cur: blocks.append((cur, a))
                cur = max(cur, b)
            if cur < end: blocks.append((cur, end))
            return blocks

        # Passada 2: aloca por crise
        for i, (on, off) in enumerate(seiz):
            zona_ini = max(0, on - MAX_PRE_S - GUARD_S)

            prev_limit = max((off_o + GUARD_S for _, off_o in seiz if off_o < on),
                             default=0)
            pre_max_disp = max(0, on - prev_limit)

            if on < MIN_ONSET:
                contexts.append({
                    'edf': edf['name'], 'path': edf['path'],
                    'dur_edf': dur, 'sz_idx': i+1,
                    'on_s': on, 'off_s': off, 'n_sz_edf': len(seiz),
                    'approved_pre': False, 'pre_max_disp_s': pre_max_disp,
                    'pre_inicio_s': None, 'pre_fim_s': None,
                    'inter_arquivo': None, 'inter_path': None,
                    'inter_inicio_s': None, 'inter_fim_s': None,
                    'inter_fonte': '--', 'valid': False,
                    'motivo': f'onset={m(on)}min < {m(MIN_ONSET)}min (MAX_PRE+GUARD)',
                }); continue

            pre_ini = on - MAX_PRE_S
            pre_colide = any(off_o < on and pre_ini < off_o + GUARD_S and on > off_o
                             for _, off_o in seiz)
            if pre_colide:
                contexts.append({
                    'edf': edf['name'], 'path': edf['path'],
                    'dur_edf': dur, 'sz_idx': i+1,
                    'on_s': on, 'off_s': off, 'n_sz_edf': len(seiz),
                    'approved_pre': False, 'pre_max_disp_s': pre_max_disp,
                    'pre_inicio_s': None, 'pre_fim_s': None,
                    'inter_arquivo': None, 'inter_path': None,
                    'inter_inicio_s': None, 'inter_fim_s': None,
                    'inter_fonte': '--', 'valid': False,
                    'motivo': 'pre-ictal colide com pos-ictal de crise anterior',
                }); continue

            r1 = free_space(0, zona_ini);     r1t = sum(b-a for a,b in r1)
            # r3 removido (pós-crise pertence ao próximo contexto)

            inter_ini = inter_fim = inter_path = None; fonte = None
            # Seleciona o ÚLTIMO segmento contíguo de r1 (= t_livre_efetivo → guard_ini).
            # r1 pode ter múltiplos segmentos se houver crises intermediárias no arquivo
            # (comum no SeizeIT2 com muitas crises por run).
            # Usar bounding box r1[0]→r1[-1] incluiria essas crises intermediárias.
            # O último segmento é: (pós-ictal_da_última_crise_intermediária, zona_ini)
            # = exatamente t_livre_efetivo até guard_ini, garantidamente livre de crises.
            last_seg = r1[-1] if r1 else None
            last_seg_dur = (last_seg[1] - last_seg[0]) if last_seg else 0
            if last_seg_dur >= MIN_INTER_S:
                inter_ini = last_seg[0]   # t_livre_efetivo
                inter_fim = last_seg[1]   # onset - MAX_PRE_S - GUARD_S
                inter_path = edf['path']; fonte = 'antes (R1-último-segmento)'

            if fonte:
                locked.append((inter_ini, inter_fim)); locked.sort()
                contexts.append({
                    'edf': edf['name'], 'path': edf['path'],
                    'dur_edf': dur, 'sz_idx': i+1,
                    'on_s': on, 'off_s': off, 'n_sz_edf': len(seiz),
                    'approved_pre': True, 'pre_max_disp_s': pre_max_disp,
                    'pre_inicio_s': on - MAX_PRE_S, 'pre_fim_s': on,
                    'inter_arquivo': edf['name'], 'inter_path': inter_path,
                    'inter_inicio_s': inter_ini, 'inter_fim_s': inter_fim,
                    'inter_fonte': fonte, 'valid': True,
                    'motivo': f'{fonte}: inter=[{m(inter_ini)}-{m(inter_fim)}min] pre=[{m(on-MAX_PRE_S)}-{m(on)}min]',
                })
            else:
                contexts.append({
                    'edf': edf['name'], 'path': edf['path'],
                    'dur_edf': dur, 'sz_idx': i+1,
                    'on_s': on, 'off_s': off, 'n_sz_edf': len(seiz),
                    'approved_pre': True, 'pre_max_disp_s': pre_max_disp,
                    'pre_inicio_s': on - MAX_PRE_S, 'pre_fim_s': on,
                    'inter_arquivo': None, 'inter_path': None,
                    'inter_inicio_s': None, 'inter_fim_s': None,
                    'inter_fonte': 'insuf', 'valid': False,
                    'motivo': f'inter insuf: R1_ultimo_seg={m(last_seg_dur)}min < {m(MIN_INTER_S)}min',
                })
    return contexts

print('Validadores definidos.')
# Out:
# Validadores definidos.

# %% [markdown]
# ## 5. Carregamento dos EDFs por paciente

# %%
def discover_all_patients(verbose=True):
    """Descobre pacientes a partir de ficheiros de ANOTAÇÃO apenas.
    Não lê nem verifica EDFs — esses só são necessários ao salvar .npz.
    """
    found = {'CHBMIT': [], 'Siena': [], 'SeizeIT2': [], 'Mendeley': []}

    # CHB-MIT: pasta chbXX com chbXX-summary.txt (anotação)
    if CHBMIT_DIR.exists():
        pats = sorted(
            d.name for d in CHBMIT_DIR.iterdir()
            if d.is_dir() and d.name.startswith('chb')
            and (d / f'{d.name}-summary.txt').exists()
        )
        found['CHBMIT'] = pats
        if verbose: print(f'CHB-MIT:  {len(pats)} pacientes em disco')

    # Siena: pasta PNXX com ficheiro de anotação *.txt
    if SIENA_DIR.exists():
        pats = sorted(
            d.name for d in SIENA_DIR.iterdir()
            if d.is_dir() and d.name.startswith('PN')
            and any(d.glob('*.txt'))
        )
        found['Siena'] = pats
        if verbose: print(f'Siena:    {len(pats)} pacientes em disco')
        if verbose: print(f'Siena:    {len(found["Siena"])} pacientes em disco')

    # SeizeIT2: pasta sub-XXX com ses-01/eeg/ contendo *.tsv (anotação BIDS)
    if SEIZEIT_DIR.exists():
        pats = sorted(
            d.name for d in SEIZEIT_DIR.iterdir()
            if d.is_dir() and d.name.startswith('sub-')
            and any((d / SEIZEIT_SESSION / 'eeg').glob('*_events.tsv'))
            if (d / SEIZEIT_SESSION / 'eeg').exists()
        )
        found['SeizeIT2'] = pats
        if verbose: print(f'SeizeIT2: {len(pats)} pacientes em disco')

    # Mendeley: pacientes conhecidos via MENDELEY_GT (anotação manual)
    found['Mendeley'] = sorted(MENDELEY_GT.keys())
    if verbose: print(f'Mendeley: {len(found["Mendeley"])} pacientes em disco')

    total = sum(len(v) for v in found.values())
    if verbose: print(f'Total em disco: {total} pacientes')
    return found

def load_patient_edfs(dataset, pat):
    """Constrói lista de EDFs a partir de ficheiros de ANOTAÇÃO apenas.
    path = caminho local SE o EDF estiver baixado; None caso contrário.
    A validação de contextos não abre EDFs — path só é usado ao salvar .npz.
    """
    edf_list = []

    if dataset == 'CHBMIT':
        pat_dir = CHBMIT_DIR / pat
        summary = pat_dir / f'{pat}-summary.txt'
        if not summary.exists(): return []
        sz_map, free_list = parse_chbmit_summary(summary)
        # Inclui TODOS os ficheiros do summary — EDF pode não estar baixado
        for fn, iv in sz_map.items():
            local = pat_dir / fn
            edf_list.append({'name': fn,
                             'path': local if local.exists() else None,
                             'dur_s': None, 'seizures': iv, 'is_pure': False})
        for fn in free_list:
            local = pat_dir / fn
            edf_list.append({'name': fn,
                             'path': local if local.exists() else None,
                             'dur_s': None, 'seizures': [], 'is_pure': True})

    elif dataset == 'Siena':
        pat_dir = SIENA_DIR / pat
        gt_s    = SIENA_GT.get(pat, {})
        ann_map = parse_siena_annotation_txt(pat_dir)  # {fn_lower: [(on,off)]}
        # Ficheiros conhecidos = união de anotação txt + SIENA_GT
        known = set(ann_map.keys()) | set(k.lower() for k in gt_s)
        for fn_lower in sorted(known):
            # Procura ficheiro local (case-insensitive)
            local = None
            for candidate in [pat_dir / fn_lower,
                               pat_dir / fn_lower.upper(),
                               pat_dir / (fn_lower[0].upper() + fn_lower[1:])]:
                if candidate.exists(): local = candidate; break
            iv = siena_match(fn_lower, gt_s) or ann_map.get(fn_lower, [])
            edf_list.append({'name': fn_lower, 'path': local,
                             'dur_s': None, 'seizures': iv,
                             'is_pure': len(iv) == 0})

    elif dataset == 'SeizeIT2':
        eeg_dir = SEIZEIT_DIR / pat / SEIZEIT_SESSION / 'eeg'
        if not eeg_dir.exists(): return []
        # Usa events.tsv (anotação BIDS) — sem abrir EDFs
        for tsv in sorted(eeg_dir.glob('*_events.tsv')):
            edf_name = tsv.name.replace('_events.tsv', '_eeg.edf')
            local    = eeg_dir / edf_name
            iv = []
            try:
                df = pd.read_csv(tsv, sep='\t')
                if 'eventType' in df.columns:
                    et = df['eventType'].astype(str).str.lower().str.strip()
                    for _, row in df[et.str.startswith('sz')].iterrows():
                        try:
                            o = float(row['onset']); d = float(row['duration'])
                            if d > 0: iv.append((o, o + d))
                        except: pass
            except: pass
            edf_list.append({'name': edf_name,
                             'path': local if local.exists() else None,
                             'dur_s': None, 'seizures': iv,
                             'is_pure': len(iv) == 0})

    elif dataset == 'Mendeley':
        edf_dir = MENDELEY_DIR / 'Raw_EDF_Files'
        if not edf_dir.exists(): edf_dir = MENDELEY_DIR
        gt = MENDELEY_GT.get(pat, {})
        for fn, iv in gt.items():
            local = edf_dir / fn
            edf_list.append({'name': fn,
                             'path': local if local.exists() else None,
                             'dur_s': None, 'seizures': iv,
                             'is_pure': len(iv) == 0})

    return edf_list

# %% [markdown]
# ## 6. Validação de todos os pacientes selecionados

# %%
# Estratégia de interictal por dataset:
# INTRA-ARQUIVO: inter = EEG antes da crise no mesmo arquivo (t_livre → guard_ini)
#   → Siena, Mendeley: gravações de sessão hospitalar, crise no final do arquivo
#   → SeizeIT2: monitorização domiciliar contínua (horas), crise em algum ponto
# DEDICADO: inter = arquivo puro de sessão separada (outro dia)
#   → CHB-MIT: arquivos de 60min gravados em sessões sem crise
# CHB-MIT → dedicado: ficheiros 1h com crises precoces não qualificam para intra
#   (threshold intra = MAX_PRE+GUARD = 65min > duração típica 60min dos ficheiros)
#   Dataset desenhado com ficheiros puros de sessão separada para interictal.
# Siena/SeizeIT2/Mendeley → intra-arquivo: gravações longas, crise tardia no ficheiro.
VALIDATORS = {
    'CHBMIT':   validate_dedicated,  # dedicado: ficheiros puros de sessão separada
    'SeizeIT2': validate_intra,        # gravações contínuas domiciliares → r1 completo
    'Siena':    validate_intra,        # sessão hospitalar → r1 completo
    'Mendeley': validate_intra,        # sessão hospitalar → r1 completo
}

# ── Passo 1: descoberta automática ───────────────────────────────────────────
print('Descobrindo pacientes em disco...')
ALL_IN_DISK = discover_all_patients(verbose=True)

# ── Passo 2: valida TODOS os pacientes disponíveis ────────────────────────────
all_contexts_full = {}   # todos os pacientes (elegíveis e não-elegíveis)
all_edfs          = {}

for dataset, pats in ALL_IN_DISK.items():
    all_contexts_full[dataset] = {}
    all_edfs[dataset]          = {}
    print(f'\n=== {dataset} ({len(pats)} pacientes) ===')
    for pat in pats:
        edf_list = load_patient_edfs(dataset, pat)
        all_edfs[dataset][pat] = edf_list
        if not edf_list:
            print(f'  {pat}: sem EDFs em disco'); continue
        ctxs = VALIDATORS[dataset](pat, edf_list)
        all_contexts_full[dataset][pat] = ctxs
        n_valid = sum(1 for c in ctxs if c['valid'])
        n_total = len(ctxs)
        tag = 'OK' if n_valid >= MIN_CONTEXTS else 'INSUF'
        print(f'  [{tag}] {pat}: {n_total} crises | {n_valid} ctx validos')

# ── Passo 3: filtra (>= MIN_CONTEXTS) e rankeia por n_valid desc ──────────────
print('\n' + '='*60)
print('SELEÇÃO AUTOMÁTICA — ranking por contextos válidos')
print('='*60)

all_contexts = {}   # apenas os selecionados
SELECTED     = {}   # dicionário final (usado pelo resto do notebook)

for dataset, pat_ctxs in all_contexts_full.items():
    # Elegíveis = >= MIN_CONTEXTS válidos
    eligible = [
        (pat, ctxs, sum(1 for c in ctxs if c['valid']))
        for pat, ctxs in pat_ctxs.items()
        if sum(1 for c in ctxs if c['valid']) >= MIN_CONTEXTS
    ]
    # Ordena por n_valid descrescente (mais contextos primeiro)
    eligible.sort(key=lambda x: -x[2])

    # Aplica cap se N_SELECT_PER_DS estiver definido
    if N_SELECT_PER_DS is not None:
        eligible = eligible[:N_SELECT_PER_DS]

    all_contexts[dataset] = {pat: ctxs for pat, ctxs, _ in eligible}
    SELECTED[dataset]     = [pat for pat, _, _ in eligible]

    print(f'\n{dataset}: {len(eligible)} selecionados de '
          f'{len(pat_ctxs)} validados')
    for pat, ctxs, n_v in eligible:
        n_t = len(ctxs)
        print(f'  #{eligible.index((pat,ctxs,n_v))+1:02d}  {pat:<14} '
              f'{n_v:3d} ctx válidos / {n_t:3d} crises')

total_pats = sum(len(v) for v in SELECTED.values())
total_ctx  = sum(sum(1 for c in ctxs if c['valid'])
                 for ds in all_contexts.values()
                 for ctxs in ds.values())
print(f'\nTotal selecionados: {total_pats} pacientes | {total_ctx} contextos')
# Out:
# Descobrindo pacientes em disco...
# CHB-MIT:  24 pacientes em disco
# Siena:    14 pacientes em disco
# Siena:    14 pacientes em disco
# SeizeIT2: 125 pacientes em disco
# Mendeley: 3 pacientes em disco
# Total em disco: 166 pacientes
#
# === CHBMIT (24 pacientes) ===
#   [INSUF] chb01: 7 crises | 1 ctx validos
#   [OK] chb02: 3 crises | 2 ctx validos
#   [INSUF] chb03: 7 crises | 1 ctx validos
#   [OK] chb04: 4 crises | 2 ctx validos
#   [INSUF] chb05: 5 crises | 1 ctx validos
#   [OK] chb06: 10 crises | 7 ctx validos
#   [OK] chb07: 3 crises | 3 ctx validos
#   [OK] chb08: 5 crises | 4 ctx validos
#   [OK] chb09: 4 crises | 4 ctx validos
#   [OK] chb10: 7 crises | 5 ctx validos
#   [INSUF] chb11: 3 crises | 1 ctx validos
#   [INSUF] chb12: 40 crises | 1 ctx validos
#   [OK] chb13: 12 crises | 2 ctx validos
#   [OK] chb14: 8 crises | 2 ctx validos
#   [INSUF] chb15: 20 crises | 1 ctx validos
#   [INSUF] chb16: 10 crises | 0 ctx validos
#   [OK] chb17: 3 crises | 2 ctx validos
#   [INSUF] chb18: 6 crises | 1 ctx validos
#   [OK] chb19: 3 crises | 2 ctx validos
#   [INSUF] chb20: 8 crises | 0 ctx validos
#   [OK] chb21: 4 crises | 2 ctx validos
#   [OK] chb22: 3 crises | 2 ctx validos
#   [OK] chb23: 7 crises | 4 ctx validos
#   [INSUF] chb24: 16 crises | 0 ctx validos
#
# === Siena (14 pacientes) ===
#   [INSUF] PN00: 4 crises | 0 ctx validos
#   [OK] PN01: 2 crises | 2 ctx validos
#   [OK] PN03: 2 crises | 2 ctx validos
#   [OK] PN05: 3 crises | 2 ctx validos
#   [INSUF] PN06: 5 crises | 1 ctx validos
#   [INSUF] PN07: 1 crises | 1 ctx validos
#   [OK] PN09: 3 crises | 3 ctx validos
#   [OK] PN10: 10 crises | 4 ctx validos
#   [INSUF] PN11: 1 crises | 1 ctx validos
#   [INSUF] PN12: 3 crises | 1 ctx validos
#   [OK] PN13: 3 crises | 3 ctx validos
#   [OK] PN14: 4 crises | 3 ctx validos
#   [OK] PN16: 2 crises | 2 ctx validos
#   [OK] PN17: 2 crises | 2 ctx validos
#
# === SeizeIT2 (125 pacientes) ===
#   [OK] sub-001: 4 crises | 4 ctx validos
#   [OK] sub-002: 15 crises | 5 ctx validos
#   [INSUF] sub-003: 1 crises | 1 ctx validos
#   [INSUF] sub-004: 4 crises | 1 ctx validos
#   [INSUF] sub-005: 2 crises | 1 ctx validos
#   [INSUF] sub-006: 1 crises | 1 ctx validos
#   [OK] sub-007: 2 crises | 2 ctx validos
#   [INSUF] sub-008: 2 crises | 1 ctx validos
#   [INSUF] sub-009: 1 crises | 1 ctx validos
#   [INSUF] sub-010: 1 crises | 1 ctx validos
#   [OK] sub-011: 4 crises | 2 ctx validos
#   [OK] sub-012: 3 crises | 3 ctx validos
#   [OK] sub-013: 2 crises | 2 ctx validos
#   [OK] sub-014: 2 crises | 2 ctx validos
#   [OK] sub-015: 9 crises | 7 ctx validos
#   [INSUF] sub-016: 2 crises | 1 ctx validos
#   [INSUF] sub-017: 1 crises | 1 ctx validos
#   [INSUF] sub-018: 1 crises | 1 ctx validos
#   [INSUF] sub-019: 1 crises | 1 ctx validos
#   [INSUF] sub-020: 1 crises | 1 ctx validos
#   [OK] sub-021: 4 crises | 4 ctx validos
#   [OK] sub-022: 7 crises | 4 ctx validos
#   [INSUF] sub-023: 1 crises | 1 ctx validos
#   [OK] sub-024: 2 crises | 2 ctx validos
#   [OK] sub-025: 3 crises | 2 ctx validos
#   [INSUF] sub-026: 4 crises | 1 ctx validos
#   [INSUF] sub-027: 1 crises | 1 ctx validos
#   [OK] sub-028: 4 crises | 3 ctx validos
#   [OK] sub-029: 4 crises | 4 ctx validos
#   [OK] sub-030: 7 crises | 5 ctx validos
#   [OK] sub-031: 3 crises | 2 ctx validos
#   [INSUF] sub-032: 1 crises | 0 ctx validos
#   [INSUF] sub-033: 1 crises | 1 ctx validos
#   [OK] sub-034: 30 crises | 4 ctx validos
#   [OK] sub-035: 55 crises | 8 ctx validos
#   [INSUF] sub-036: 3 crises | 1 ctx validos
#   [INSUF] sub-037: 2 crises | 1 ctx validos
#   [INSUF] sub-038: 1 crises | 1 ctx validos
#   [OK] sub-039: 75 crises | 9 ctx validos
#   [OK] sub-040: 3 crises | 3 ctx validos
#   [INSUF] sub-041: 2 crises | 1 ctx validos
#   [OK] sub-042: 11 crises | 5 ctx validos
#   [OK] sub-043: 5 crises | 2 ctx validos
#   [OK] sub-044: 4 crises | 2 ctx validos
#   [INSUF] sub-045: 2 crises | 0 ctx validos
#   [OK] sub-046: 4 crises | 2 ctx validos
#   [OK] sub-047: 64 crises | 7 ctx validos
#   [INSUF] sub-048: 1 crises | 1 ctx validos
#   [INSUF] sub-049: 1 crises | 1 ctx validos
#   [INSUF] sub-050: 3 crises | 1 ctx validos
#   [OK] sub-051: 5 crises | 4 ctx validos
#   [OK] sub-052: 9 crises | 8 ctx validos
#   [OK] sub-053: 2 crises | 2 ctx validos
#   [INSUF] sub-054: 1 crises | 1 ctx validos
#   [OK] sub-055: 8 crises | 3 ctx validos
#   [OK] sub-056: 13 crises | 8 ctx validos
#   [INSUF] sub-057: 1 crises | 1 ctx validos
#   [INSUF] sub-058: 1 crises | 0 ctx validos
#   [OK] sub-059: 8 crises | 2 ctx validos
#   [OK] sub-060: 25 crises | 5 ctx validos
#   [INSUF] sub-061: 1 crises | 1 ctx validos
#   [OK] sub-062: 3 crises | 2 ctx validos
#   [OK] sub-063: 2 crises | 2 ctx validos
#   [OK] sub-064: 3 crises | 3 ctx validos
#   [OK] sub-065: 2 crises | 2 ctx validos
#   [OK] sub-066: 4 crises | 3 ctx validos
#   [INSUF] sub-067: 4 crises | 1 ctx validos
#   [OK] sub-068: 3 crises | 2 ctx validos
#   [INSUF] sub-069: 1 crises | 1 ctx validos
#   [INSUF] sub-070: 2 crises | 1 ctx validos
#   [OK] sub-071: 6 crises | 3 ctx validos
#   [OK] sub-072: 20 crises | 4 ctx validos
#   [OK] sub-073: 75 crises | 12 ctx validos
#   [OK] sub-074: 9 crises | 3 ctx validos
#   [INSUF] sub-075: 2 crises | 1 ctx validos
#   [INSUF] sub-076: 3 crises | 1 ctx validos
#   [OK] sub-077: 9 crises | 2 ctx validos
#   [INSUF] sub-078: 1 crises | 1 ctx validos
#   [OK] sub-079: 15 crises | 3 ctx validos
#   [OK] sub-080: 8 crises | 4 ctx validos
#   [INSUF] sub-081: 4 crises | 0 ctx validos
#   [OK] sub-082: 4 crises | 3 ctx validos
#   [INSUF] sub-083: 1 crises | 0 ctx validos
#   [INSUF] sub-084: 4 crises | 0 ctx validos
#   [INSUF] sub-085: 3 crises | 0 ctx validos
#   [INSUF] sub-086: 4 crises | 0 ctx validos
#   [INSUF] sub-087: 42 crises | 0 ctx validos
#   [INSUF] sub-088: 1 crises | 0 ctx validos
#   [INSUF] sub-089: 5 crises | 0 ctx validos
#   [INSUF] sub-090: 4 crises | 0 ctx validos
#   [INSUF] sub-091: 5 crises | 0 ctx validos
#   [INSUF] sub-092: 6 crises | 0 ctx validos
#   [INSUF] sub-093: 1 crises | 0 ctx validos
#   [INSUF] sub-094: 3 crises | 0 ctx validos
#   [INSUF] sub-095: 1 crises | 0 ctx validos
#   [INSUF] sub-096: 1 crises | 0 ctx validos
#   [OK] sub-097: 13 crises | 6 ctx validos
#   [INSUF] sub-098: 1 crises | 1 ctx validos
#   [OK] sub-099: 4 crises | 2 ctx validos
#   [INSUF] sub-100: 2 crises | 0 ctx validos
#   [OK] sub-101: 7 crises | 3 ctx validos
#   [OK] sub-102: 3 crises | 2 ctx validos
#   [OK] sub-103: 15 crises | 7 ctx validos
#   [INSUF] sub-104: 2 crises | 1 ctx validos
#   [OK] sub-105: 2 crises | 2 ctx validos
#   [INSUF] sub-106: 2 crises | 1 ctx validos
#   [INSUF] sub-107: 2 crises | 1 ctx validos
#   [OK] sub-108: 2 crises | 2 ctx validos
#   [OK] sub-109: 37 crises | 2 ctx validos
#   [INSUF] sub-110: 2 crises | 1 ctx validos
#   [OK] sub-111: 2 crises | 2 ctx validos
#   [OK] sub-112: 7 crises | 4 ctx validos
#   [OK] sub-113: 10 crises | 8 ctx validos
#   [OK] sub-114: 4 crises | 3 ctx validos
#   [OK] sub-115: 7 crises | 5 ctx validos
#   [OK] sub-116: 7 crises | 4 ctx validos
#   [OK] sub-117: 11 crises | 2 ctx validos
#   [INSUF] sub-118: 2 crises | 1 ctx validos
#   [INSUF] sub-119: 14 crises | 1 ctx validos
#   [INSUF] sub-120: 10 crises | 0 ctx validos
#   [INSUF] sub-121: 4 crises | 0 ctx validos
#   [INSUF] sub-122: 4 crises | 0 ctx validos
#   [INSUF] sub-123: 2 crises | 0 ctx validos
#   [INSUF] sub-124: 1 crises | 0 ctx validos
#   [INSUF] sub-125: 2 crises | 0 ctx validos
#
# === Mendeley (3 pacientes) ===
#   [OK] p10: 2 crises | 2 ctx validos
#   [OK] p13: 6 crises | 2 ctx validos
#   [OK] p15: 5 crises | 3 ctx validos
#
# ============================================================
# SELEÇÃO AUTOMÁTICA — ranking por contextos válidos
# ============================================================
#
# CHBMIT: 14 selecionados de 24 validados
#   #01  chb06            7 ctx válidos /  10 crises
#   #02  chb10            5 ctx válidos /   7 crises
#   #03  chb08            4 ctx válidos /   5 crises
#   #04  chb09            4 ctx válidos /   4 crises
#   #05  chb23            4 ctx válidos /   7 crises
#   #06  chb07            3 ctx válidos /   3 crises
#   #07  chb02            2 ctx válidos /   3 crises
#   #08  chb04            2 ctx válidos /   4 crises
#   #09  chb13            2 ctx válidos /  12 crises
#   #10  chb14            2 ctx válidos /   8 crises
#   #11  chb17            2 ctx válidos /   3 crises
#   #12  chb19            2 ctx válidos /   3 crises
#   #13  chb21            2 ctx válidos /   4 crises
#   #14  chb22            2 ctx válidos /   3 crises
#
# Siena: 9 selecionados de 14 validados
#   #01  PN10             4 ctx válidos /  10 crises
#   #02  PN09             3 ctx válidos /   3 crises
#   #03  PN13             3 ctx válidos /   3 crises
#   #04  PN14             3 ctx válidos /   4 crises
#   #05  PN01             2 ctx válidos /   2 crises
#   #06  PN03             2 ctx válidos /   2 crises
#   #07  PN05             2 ctx válidos /   3 crises
#   #08  PN16             2 ctx válidos /   2 crises
#   #09  PN17             2 ctx válidos /   2 crises
#
# SeizeIT2: 61 selecionados de 125 validados
#   #01  sub-073         12 ctx válidos /  75 crises
#   #02  sub-039          9 ctx válidos /  75 crises
#   #03  sub-035          8 ctx válidos /  55 crises
#   #04  sub-052          8 ctx válidos /   9 crises
#   #05  sub-056          8 ctx válidos /  13 crises
#   #06  sub-113          8 ctx válidos /  10 crises
#   #07  sub-015          7 ctx válidos /   9 crises
#   #08  sub-047          7 ctx válidos /  64 crises
#   #09  sub-103          7 ctx válidos /  15 crises
#   #10  sub-097          6 ctx válidos /  13 crises
#   #11  sub-002          5 ctx válidos /  15 crises
#   #12  sub-030          5 ctx válidos /   7 crises
#   #13  sub-042          5 ctx válidos /  11 crises
#   #14  sub-060          5 ctx válidos /  25 crises
#   #15  sub-115          5 ctx válidos /   7 crises
#   #16  sub-001          4 ctx válidos /   4 crises
#   #17  sub-021          4 ctx válidos /   4 crises
#   #18  sub-022          4 ctx válidos /   7 crises
#   #19  sub-029          4 ctx válidos /   4 crises
#   #20  sub-034          4 ctx válidos /  30 crises
#   #21  sub-051          4 ctx válidos /   5 crises
#   #22  sub-072          4 ctx válidos /  20 crises
#   #23  sub-080          4 ctx válidos /   8 crises
#   #24  sub-112          4 ctx válidos /   7 crises
#   #25  sub-116          4 ctx válidos /   7 crises
#   #26  sub-012          3 ctx válidos /   3 crises
#   #27  sub-028          3 ctx válidos /   4 crises
#   #28  sub-040          3 ctx válidos /   3 crises
#   #29  sub-055          3 ctx válidos /   8 crises
#   #30  sub-064          3 ctx válidos /   3 crises
#   #31  sub-066          3 ctx válidos /   4 crises
#   #32  sub-071          3 ctx válidos /   6 crises
#   #33  sub-074          3 ctx válidos /   9 crises
#   #34  sub-079          3 ctx válidos /  15 crises
#   #35  sub-082          3 ctx válidos /   4 crises
#   #36  sub-101          3 ctx válidos /   7 crises
#   #37  sub-114          3 ctx válidos /   4 crises
#   #38  sub-007          2 ctx válidos /   2 crises
#   #39  sub-011          2 ctx válidos /   4 crises
#   #40  sub-013          2 ctx válidos /   2 crises
#   #41  sub-014          2 ctx válidos /   2 crises
#   #42  sub-024          2 ctx válidos /   2 crises
#   #43  sub-025          2 ctx válidos /   3 crises
#   #44  sub-031          2 ctx válidos /   3 crises
#   #45  sub-043          2 ctx válidos /   5 crises
#   #46  sub-044          2 ctx válidos /   4 crises
#   #47  sub-046          2 ctx válidos /   4 crises
#   #48  sub-053          2 ctx válidos /   2 crises
#   #49  sub-059          2 ctx válidos /   8 crises
#   #50  sub-062          2 ctx válidos /   3 crises
#   #51  sub-063          2 ctx válidos /   2 crises
#   #52  sub-065          2 ctx válidos /   2 crises
#   #53  sub-068          2 ctx válidos /   3 crises
#   #54  sub-077          2 ctx válidos /   9 crises
#   #55  sub-099          2 ctx válidos /   4 crises
#   #56  sub-102          2 ctx válidos /   3 crises
#   #57  sub-105          2 ctx válidos /   2 crises
#   #58  sub-108          2 ctx válidos /   2 crises
#   #59  sub-109          2 ctx válidos /  37 crises
#   #60  sub-111          2 ctx válidos /   2 crises
#   #61  sub-117          2 ctx válidos /  11 crises
#
# Mendeley: 3 selecionados de 3 validados
#   #01  p15              3 ctx válidos /   5 crises
#   #02  p10              2 ctx válidos /   2 crises
#   #03  p13              2 ctx válidos /   6 crises
#
# Total selecionados: 87 pacientes | 302 contextos

# %% [markdown]
# ## 7. Verificação de integridade

# %%
def check_integrity(dataset, pat, edf_list, contexts):
    problems = []
    sz_by_file = {e['name']: e['seizures'] for e in edf_list}
    valid_ctxs = [c for c in contexts if c['valid']]

    for c in valid_ctxs:
        if c['inter_inicio_s'] is None: continue
        arq = c['inter_arquivo']
        ii, if_ = c['inter_inicio_s'], c['inter_fim_s']
        for (con, coff) in sz_by_file.get(arq, []):
            if ii < coff and if_ > con:
                problems.append(f'{pat} ctx#{c["sz_idx"]}: interictal contem crise em {arq}')

    for c in valid_ctxs:
        if c['pre_inicio_s'] is None: continue
        arq = c['edf']
        pre_i, pre_f = c['pre_inicio_s'], c['pre_fim_s']
        for (con, coff) in sz_by_file.get(arq, []):
            if coff >= c['on_s']: continue
            if pre_i < coff + GUARD_S and pre_f > coff:
                problems.append(f'{pat} ctx#{c["sz_idx"]}: pre-ictal colide pos-ictal anterior')

    inter_by_file = defaultdict(list)
    for c in valid_ctxs:
        if c['inter_inicio_s'] is not None:
            inter_by_file[c['inter_arquivo']].append(
                (c['inter_inicio_s'], c['inter_fim_s'], c['sz_idx']))
    for arq, ivs in inter_by_file.items():
        ivs.sort()
        for a in range(len(ivs)-1):
            if ivs[a][1] > ivs[a+1][0]:
                problems.append(f'{pat}: interictais sobrepostos em {arq}: '
                                 f'ctx#{ivs[a][2]} e ctx#{ivs[a+1][2]}')
    return problems

print('VERIFICAÇÃO DE INTEGRIDADE')
print('='*55)
total_problems = 0
for dataset, pats in SELECTED.items():
    for pat in pats:
        if pat not in all_contexts.get(dataset, {}): continue
        probs = check_integrity(dataset, pat,
                                all_edfs[dataset][pat],
                                all_contexts[dataset][pat])
        if probs:
            total_problems += len(probs)
            for p in probs: print(f'  PROBLEMA: {p}')

if total_problems == 0:
    print('TUDO OK — nenhuma violação encontrada.')
else:
    print(f'{total_problems} problema(s) encontrado(s).')
# Out:
# VERIFICAÇÃO DE INTEGRIDADE
# =======================================================
# TUDO OK — nenhuma violação encontrada.

# %% [markdown]
# ## 8. Tabela detalhada de contextos por paciente
#
# Para cada paciente: todos os contextos (válidos e inválidos), com:
# - Arquivo EDF da crise e duração
# - Onset e offset (min)
# - Tipo de interictal (dedicado / R1 / R3 / R1+R3)
# - Arquivo fonte do interictal e trecho exato [início – fim] em min
# - Pré-ictal máximo disponível
# - Status do contexto e motivo

# %%
def print_tabela_paciente(dataset, pat, contexts):
    n_valid = sum(1 for c in contexts if c['valid'])
    tipo_ds = 'dedicado' if dataset in ('CHBMIT',) else 'intra-arquivo'
    print(f'\n' + '─'*80)
    print(f'  {dataset} / {pat}  [{tipo_ds}]  —  {n_valid}/{len(contexts)} contextos válidos')
    print('─'*80)
    ctx_num = 0
    for c in contexts:
        if c['valid']: ctx_num += 1
        status = f'✓ CONTEXTO {ctx_num}' if c['valid'] else '✗ inválido'
        print(f'  Crise #{c["sz_idx"]:2d} | {c["edf"]}  ({m(c["dur_edf"] or 0):.0f}min)')
        print(f'    Onset : {m(c["on_s"]):7.1f} min  ({fmt_hms(c["on_s"])})')
        print(f'    Offset: {m(c["off_s"]):7.1f} min  ({fmt_hms(c["off_s"])})  '
              f'dur={m(c["off_s"]-c["on_s"]):.1f}min')
        print(f'    Pré-ictal máx disp: {m(c["pre_max_disp_s"]):.1f} min', end='')
        if c['approved_pre'] and c['pre_inicio_s'] is not None:
            print(f'  →  reservado [{m(c["pre_inicio_s"]):.1f} – {m(c["pre_fim_s"]):.1f}min]')
        else:
            print()
        if c['valid']:
            ii, if_ = c['inter_inicio_s'], c['inter_fim_s']
            print(f'    Interictal : {c["inter_fonte"]}  |  arquivo: {c["inter_arquivo"]}')
            print(f'                 [{m(ii):.1f} – {m(if_):.1f} min]  ({m(if_-ii):.0f}min)')
        else:
            print(f'    Motivo     : {c["motivo"]}')
        print(f'    Status     : {status}')

for dataset, pats in SELECTED.items():
    for pat in pats:
        if pat not in all_contexts.get(dataset, {}): continue
        print_tabela_paciente(dataset, pat, all_contexts[dataset][pat])

# Resumo consolidado
print('\n' + '='*80)
print('RESUMO CONSOLIDADO')
print('='*80)
print(f'  {"Dataset":<12} {"Paciente":<12} {"Crises":<8} {"Ctx val":<10} '
      f'{"Selecionável?":<15} {"Fonte inter"}')
print('  ' + '-'*74)
total_sel = 0; total_ctx_val = 0; total_crises = 0
for dataset, pats in SELECTED.items():
    for pat in pats:
        if pat not in all_contexts.get(dataset, {}): continue
        ctxs = all_contexts[dataset][pat]
        n_val = sum(1 for c in ctxs if c['valid'])
        n_tot = len(ctxs)
        sel = 'Sim ✓' if n_val >= MIN_CONTEXTS else 'Não ✗'
        tipo = 'dedicado' if dataset in ('CHBMIT',) else 'intra-arquivo'
        print(f'  {dataset:<12} {pat:<12} {n_tot:<8} {n_val:<10} {sel:<15} {tipo}')
        if n_val >= MIN_CONTEXTS: total_sel += 1
        total_ctx_val += n_val; total_crises += n_tot
print('  ' + '-'*74)
print(f'  {"TOTAL":<12} {"24 pac":<12} {total_crises:<8} {total_ctx_val:<10} '
      f'{str(total_sel)+" pac sel":<15}')
print(f'\nParâmetros: G={int(GUARD_S//60)}min  P={int(MAX_PRE_S//60)}min  I={int(MIN_INTER_S//60)}min  '
      f'MIN_CTX={MIN_CONTEXTS}')
# Out:
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb06  [dedicado]  —  7/10 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb06_01.edf  (0min)
#     Onset :    28.7 min  (00:28:44)
#     Offset:    29.0 min  (00:28:58)  dur=0.2min
#     Pré-ictal máx disp: 28.7 min
#     Motivo     : onset=28.7min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb06_01.edf  (0min)
#     Onset :   124.3 min  (02:04:21)
#     Offset:   124.6 min  (02:04:36)  dur=0.2min
#     Pré-ictal máx disp: 65.4 min  →  reservado [84.3 – 124.3min]
#     Interictal : dedicado  |  arquivo: chb06_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 3 | chb06_01.edf  (0min)
#     Onset :   225.4 min  (03:45:25)
#     Offset:   225.7 min  (03:45:40)  dur=0.2min
#     Pré-ictal máx disp: 70.8 min  →  reservado [185.4 – 225.4min]
#     Interictal : dedicado  |  arquivo: chb06_03.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb06_04.edf  (0min)
#     Onset :     5.5 min  (00:05:27)
#     Offset:     5.8 min  (00:05:47)  dur=0.3min
#     Pré-ictal máx disp: 5.5 min
#     Motivo     : onset=5.5min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb06_04.edf  (0min)
#     Onset :   103.5 min  (01:43:31)
#     Offset:   103.8 min  (01:43:51)  dur=0.3min
#     Pré-ictal máx disp: 67.7 min  →  reservado [63.5 – 103.5min]
#     Interictal : dedicado  |  arquivo: chb06_05.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 1 | chb06_09.edf  (0min)
#     Onset :   208.3 min  (03:28:20)
#     Offset:   208.6 min  (03:28:36)  dur=0.3min
#     Pré-ictal máx disp: 208.3 min  →  reservado [168.3 – 208.3min]
#     Interictal : dedicado  |  arquivo: chb06_06.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 4
#   Crise # 1 | chb06_10.edf  (0min)
#     Onset :   180.6 min  (03:00:33)
#     Offset:   180.8 min  (03:00:45)  dur=0.2min
#     Pré-ictal máx disp: 180.6 min  →  reservado [140.6 – 180.6min]
#     Interictal : dedicado  |  arquivo: chb06_07.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 5
#   Crise # 1 | chb06_13.edf  (0min)
#     Onset :     8.4 min  (00:08:26)
#     Offset:     8.7 min  (00:08:39)  dur=0.2min
#     Pré-ictal máx disp: 8.4 min
#     Motivo     : onset=8.4min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb06_18.edf  (0min)
#     Onset :   130.0 min  (02:09:59)
#     Offset:   130.2 min  (02:10:11)  dur=0.2min
#     Pré-ictal máx disp: 130.0 min  →  reservado [90.0 – 130.0min]
#     Interictal : dedicado  |  arquivo: chb06_08.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 6
#   Crise # 1 | chb06_24.edf  (0min)
#     Onset :   156.4 min  (02:36:27)
#     Offset:   156.7 min  (02:36:43)  dur=0.3min
#     Pré-ictal máx disp: 156.4 min  →  reservado [116.5 – 156.4min]
#     Interictal : dedicado  |  arquivo: chb06_12.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 7
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb10  [dedicado]  —  5/7 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb10_12.edf  (0min)
#     Onset :   105.2 min  (01:45:13)
#     Offset:   105.8 min  (01:45:48)  dur=0.6min
#     Pré-ictal máx disp: 105.2 min  →  reservado [65.2 – 105.2min]
#     Interictal : dedicado  |  arquivo: chb10_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb10_20.edf  (0min)
#     Onset :   114.8 min  (01:54:48)
#     Offset:   116.0 min  (01:55:58)  dur=1.2min
#     Pré-ictal máx disp: 114.8 min  →  reservado [74.8 – 114.8min]
#     Interictal : dedicado  |  arquivo: chb10_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb10_27.edf  (0min)
#     Onset :    39.7 min  (00:39:42)
#     Offset:    40.8 min  (00:40:47)  dur=1.1min
#     Pré-ictal máx disp: 39.7 min
#     Motivo     : onset=39.7min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb10_30.edf  (0min)
#     Onset :    50.4 min  (00:50:21)
#     Offset:    51.3 min  (00:51:19)  dur=1.0min
#     Pré-ictal máx disp: 50.4 min  →  reservado [10.3 – 50.4min]
#     Interictal : dedicado  |  arquivo: chb10_03.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 1 | chb10_31.edf  (0min)
#     Onset :    63.4 min  (01:03:21)
#     Offset:    64.6 min  (01:04:37)  dur=1.3min
#     Pré-ictal máx disp: 63.4 min  →  reservado [23.4 – 63.4min]
#     Interictal : dedicado  |  arquivo: chb10_04.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 4
#   Crise # 1 | chb10_38.edf  (0min)
#     Onset :    77.0 min  (01:16:58)
#     Offset:    78.5 min  (01:18:27)  dur=1.5min
#     Pré-ictal máx disp: 77.0 min  →  reservado [37.0 – 77.0min]
#     Interictal : dedicado  |  arquivo: chb10_05.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 5
#   Crise # 1 | chb10_89.edf  (0min)
#     Onset :    23.1 min  (00:23:03)
#     Offset:    23.9 min  (00:23:57)  dur=0.9min
#     Pré-ictal máx disp: 23.1 min
#     Motivo     : onset=23.1min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb08  [dedicado]  —  4/5 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb08_02.edf  (0min)
#     Onset :    44.5 min  (00:44:30)
#     Offset:    47.4 min  (00:47:21)  dur=2.9min
#     Pré-ictal máx disp: 44.5 min  →  reservado [4.5 – 44.5min]
#     Interictal : dedicado  |  arquivo: chb08_03.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb08_05.edf  (0min)
#     Onset :    47.6 min  (00:47:36)
#     Offset:    50.8 min  (00:50:46)  dur=3.2min
#     Pré-ictal máx disp: 47.6 min  →  reservado [7.6 – 47.6min]
#     Interictal : dedicado  |  arquivo: chb08_04.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb08_11.edf  (0min)
#     Onset :    49.8 min  (00:49:48)
#     Offset:    52.0 min  (00:52:02)  dur=2.2min
#     Pré-ictal máx disp: 49.8 min  →  reservado [9.8 – 49.8min]
#     Interictal : dedicado  |  arquivo: chb08_10.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 1 | chb08_13.edf  (0min)
#     Onset :    40.3 min  (00:40:17)
#     Offset:    43.0 min  (00:42:57)  dur=2.7min
#     Pré-ictal máx disp: 40.3 min  →  reservado [0.3 – 40.3min]
#     Interictal : dedicado  |  arquivo: chb08_12.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 4
#   Crise # 1 | chb08_21.edf  (0min)
#     Onset :    34.7 min  (00:34:43)
#     Offset:    39.1 min  (00:39:07)  dur=4.4min
#     Pré-ictal máx disp: 34.7 min
#     Motivo     : onset=34.7min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb09  [dedicado]  —  4/4 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb09_06.edf  (0min)
#     Onset :   203.8 min  (03:23:51)
#     Offset:   204.9 min  (03:24:55)  dur=1.1min
#     Pré-ictal máx disp: 203.8 min  →  reservado [163.8 – 203.8min]
#     Interictal : dedicado  |  arquivo: chb09_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb09_08.edf  (0min)
#     Onset :    49.2 min  (00:49:11)
#     Offset:    50.5 min  (00:50:30)  dur=1.3min
#     Pré-ictal máx disp: 49.2 min  →  reservado [9.2 – 49.2min]
#     Interictal : dedicado  |  arquivo: chb09_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 2 | chb09_08.edf  (0min)
#     Onset :   153.3 min  (02:33:16)
#     Offset:   154.4 min  (02:34:27)  dur=1.2min
#     Pré-ictal máx disp: 72.8 min  →  reservado [113.3 – 153.3min]
#     Interictal : dedicado  |  arquivo: chb09_03.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 1 | chb09_19.edf  (0min)
#     Onset :    88.3 min  (01:28:19)
#     Offset:    89.3 min  (01:29:21)  dur=1.0min
#     Pré-ictal máx disp: 88.3 min  →  reservado [48.3 – 88.3min]
#     Interictal : dedicado  |  arquivo: chb09_04.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 4
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb23  [dedicado]  —  4/7 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb23_06.edf  (0min)
#     Onset :    66.0 min  (01:06:02)
#     Offset:    67.9 min  (01:07:55)  dur=1.9min
#     Pré-ictal máx disp: 66.0 min  →  reservado [26.0 – 66.0min]
#     Interictal : dedicado  |  arquivo: chb23_07.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb23_08.edf  (0min)
#     Onset :     5.4 min  (00:05:25)
#     Offset:     5.8 min  (00:05:45)  dur=0.3min
#     Pré-ictal máx disp: 5.4 min
#     Motivo     : onset=5.4min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb23_08.edf  (0min)
#     Onset :    85.1 min  (01:25:04)
#     Offset:    85.8 min  (01:25:51)  dur=0.8min
#     Pré-ictal máx disp: 49.3 min  →  reservado [45.1 – 85.1min]
#     Interictal : dedicado  |  arquivo: chb23_10.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb23_09.edf  (0min)
#     Onset :    43.1 min  (00:43:09)
#     Offset:    44.3 min  (00:44:20)  dur=1.2min
#     Pré-ictal máx disp: 43.1 min  →  reservado [3.1 – 43.1min]
#     Interictal : dedicado  |  arquivo: chb23_16.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 2 | chb23_09.edf  (0min)
#     Onset :   114.8 min  (01:54:45)
#     Offset:   115.8 min  (01:55:47)  dur=1.0min
#     Pré-ictal máx disp: 40.4 min  →  reservado [74.8 – 114.8min]
#     Interictal : dedicado  |  arquivo: chb23_17.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 4
#   Crise # 3 | chb23_09.edf  (0min)
#     Onset :   141.8 min  (02:21:45)
#     Offset:   142.2 min  (02:22:12)  dur=0.5min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal contem crise #2
#     Status     : ✗ inválido
#   Crise # 4 | chb23_09.edf  (0min)
#     Onset :   159.7 min  (02:39:40)
#     Offset:   161.1 min  (02:41:04)  dur=1.4min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide pos-ictal crise #2
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb07  [dedicado]  —  3/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb07_12.edf  (0min)
#     Onset :    82.0 min  (01:22:00)
#     Offset:    83.4 min  (01:23:26)  dur=1.4min
#     Pré-ictal máx disp: 82.0 min  →  reservado [42.0 – 82.0min]
#     Interictal : dedicado  |  arquivo: chb07_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb07_13.edf  (0min)
#     Onset :    54.8 min  (00:54:45)
#     Offset:    56.4 min  (00:56:21)  dur=1.6min
#     Pré-ictal máx disp: 54.8 min  →  reservado [14.8 – 54.8min]
#     Interictal : dedicado  |  arquivo: chb07_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb07_19.edf  (0min)
#     Onset :   228.1 min  (03:48:08)
#     Offset:   230.5 min  (03:50:31)  dur=2.4min
#     Pré-ictal máx disp: 228.1 min  →  reservado [188.1 – 228.1min]
#     Interictal : dedicado  |  arquivo: chb07_03.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 3
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb02  [dedicado]  —  2/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb02_16+.edf  (0min)
#     Onset :    49.5 min  (00:49:32)
#     Offset:    50.9 min  (00:50:53)  dur=1.4min
#     Pré-ictal máx disp: 49.5 min  →  reservado [9.5 – 49.5min]
#     Interictal : dedicado  |  arquivo: chb02_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb02_16.edf  (0min)
#     Onset :     2.2 min  (00:02:10)
#     Offset:     3.5 min  (00:03:32)  dur=1.4min
#     Pré-ictal máx disp: 2.2 min
#     Motivo     : onset=2.2min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb02_19.edf  (0min)
#     Onset :    56.1 min  (00:56:09)
#     Offset:    56.3 min  (00:56:18)  dur=0.1min
#     Pré-ictal máx disp: 56.1 min  →  reservado [16.1 – 56.1min]
#     Interictal : dedicado  |  arquivo: chb02_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb04  [dedicado]  —  2/4 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb04_05.edf  (0min)
#     Onset :   130.1 min  (02:10:04)
#     Offset:   130.9 min  (02:10:53)  dur=0.8min
#     Pré-ictal máx disp: 130.1 min  →  reservado [90.1 – 130.1min]
#     Interictal : dedicado  |  arquivo: chb04_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb04_08.edf  (0min)
#     Onset :   107.4 min  (01:47:26)
#     Offset:   109.3 min  (01:49:17)  dur=1.9min
#     Pré-ictal máx disp: 107.4 min  →  reservado [67.4 – 107.4min]
#     Interictal : dedicado  |  arquivo: chb04_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb04_28.edf  (0min)
#     Onset :    28.0 min  (00:27:59)
#     Offset:    29.7 min  (00:29:41)  dur=1.7min
#     Pré-ictal máx disp: 28.0 min
#     Motivo     : onset=28.0min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb04_28.edf  (0min)
#     Onset :    63.0 min  (01:03:02)
#     Offset:    65.0 min  (01:04:58)  dur=1.9min
#     Pré-ictal máx disp: 3.4 min
#     Motivo     : pre-ictal contem crise #1
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb13  [dedicado]  —  2/12 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb13_19.edf  (0min)
#     Onset :    34.6 min  (00:34:37)
#     Offset:    35.4 min  (00:35:21)  dur=0.7min
#     Pré-ictal máx disp: 34.6 min
#     Motivo     : onset=34.6min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb13_21.edf  (0min)
#     Onset :    15.6 min  (00:15:34)
#     Offset:    16.7 min  (00:16:44)  dur=1.2min
#     Pré-ictal máx disp: 15.6 min
#     Motivo     : onset=15.6min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb13_40.edf  (0min)
#     Onset :     2.4 min  (00:02:22)
#     Offset:     2.9 min  (00:02:53)  dur=0.5min
#     Pré-ictal máx disp: 2.4 min
#     Motivo     : onset=2.4min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb13_40.edf  (0min)
#     Onset :     8.8 min  (00:08:50)
#     Offset:     9.9 min  (00:09:54)  dur=1.1min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=8.8min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb13_55.edf  (0min)
#     Onset :     7.6 min  (00:07:38)
#     Offset:     8.0 min  (00:07:58)  dur=0.3min
#     Pré-ictal máx disp: 7.6 min
#     Motivo     : onset=7.6min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb13_55.edf  (0min)
#     Onset :    40.6 min  (00:40:36)
#     Offset:    40.9 min  (00:40:54)  dur=0.3min
#     Pré-ictal máx disp: 2.6 min
#     Motivo     : pre-ictal contem crise #1
#     Status     : ✗ inválido
#   Crise # 1 | chb13_58.edf  (0min)
#     Onset :    41.2 min  (00:41:14)
#     Offset:    41.5 min  (00:41:31)  dur=0.3min
#     Pré-ictal máx disp: 41.2 min  →  reservado [1.2 – 41.2min]
#     Interictal : dedicado  |  arquivo: chb13_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb13_59.edf  (0min)
#     Onset :    55.6 min  (00:55:39)
#     Offset:    56.7 min  (00:56:41)  dur=1.0min
#     Pré-ictal máx disp: 55.6 min  →  reservado [15.7 – 55.6min]
#     Interictal : dedicado  |  arquivo: chb13_03.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb13_60.edf  (0min)
#     Onset :    10.6 min  (00:10:38)
#     Offset:    11.0 min  (00:11:00)  dur=0.4min
#     Pré-ictal máx disp: 10.6 min
#     Motivo     : onset=10.6min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb13_62.edf  (0min)
#     Onset :    14.2 min  (00:14:11)
#     Offset:    15.3 min  (00:15:16)  dur=1.1min
#     Pré-ictal máx disp: 14.2 min
#     Motivo     : onset=14.2min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb13_62.edf  (0min)
#     Onset :    27.1 min  (00:27:06)
#     Offset:    28.2 min  (00:28:11)  dur=1.1min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=27.1min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 3 | chb13_62.edf  (0min)
#     Onset :    44.4 min  (00:44:24)
#     Offset:    45.4 min  (00:45:21)  dur=0.9min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal contem crise #1
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb14  [dedicado]  —  2/8 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb14_03.edf  (0min)
#     Onset :    33.1 min  (00:33:06)
#     Offset:    33.3 min  (00:33:20)  dur=0.2min
#     Pré-ictal máx disp: 33.1 min
#     Motivo     : onset=33.1min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb14_04.edf  (0min)
#     Onset :    22.9 min  (00:22:52)
#     Offset:    23.2 min  (00:23:12)  dur=0.3min
#     Pré-ictal máx disp: 22.9 min
#     Motivo     : onset=22.9min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 2 | chb14_04.edf  (0min)
#     Onset :    47.0 min  (00:46:57)
#     Offset:    47.3 min  (00:47:19)  dur=0.4min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal contem crise #1
#     Status     : ✗ inválido
#   Crise # 1 | chb14_06.edf  (0min)
#     Onset :    31.9 min  (00:31:51)
#     Offset:    32.1 min  (00:32:05)  dur=0.2min
#     Pré-ictal máx disp: 31.9 min
#     Motivo     : onset=31.9min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb14_11.edf  (0min)
#     Onset :    30.6 min  (00:30:38)
#     Offset:    31.3 min  (00:31:19)  dur=0.7min
#     Pré-ictal máx disp: 30.6 min
#     Motivo     : onset=30.6min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb14_17.edf  (0min)
#     Onset :    54.0 min  (00:53:59)
#     Offset:    54.3 min  (00:54:19)  dur=0.3min
#     Pré-ictal máx disp: 54.0 min  →  reservado [14.0 – 54.0min]
#     Interictal : dedicado  |  arquivo: chb14_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb14_18.edf  (0min)
#     Onset :    17.3 min  (00:17:19)
#     Offset:    17.7 min  (00:17:41)  dur=0.4min
#     Pré-ictal máx disp: 17.3 min
#     Motivo     : onset=17.3min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb14_27.edf  (0min)
#     Onset :    47.2 min  (00:47:13)
#     Offset:    47.5 min  (00:47:29)  dur=0.3min
#     Pré-ictal máx disp: 47.2 min  →  reservado [7.2 – 47.2min]
#     Interictal : dedicado  |  arquivo: chb14_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb17  [dedicado]  —  2/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb17a_03.edf  (0min)
#     Onset :    38.0 min  (00:38:02)
#     Offset:    39.5 min  (00:39:32)  dur=1.5min
#     Pré-ictal máx disp: 38.0 min
#     Motivo     : onset=38.0min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb17a_04.edf  (0min)
#     Onset :    50.4 min  (00:50:25)
#     Offset:    52.3 min  (00:52:20)  dur=1.9min
#     Pré-ictal máx disp: 50.4 min  →  reservado [10.4 – 50.4min]
#     Interictal : dedicado  |  arquivo: chb17a_05.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb17b_63.edf  (0min)
#     Onset :    52.3 min  (00:52:16)
#     Offset:    53.7 min  (00:53:44)  dur=1.5min
#     Pré-ictal máx disp: 52.3 min  →  reservado [12.3 – 52.3min]
#     Interictal : dedicado  |  arquivo: chb17a_06.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb19  [dedicado]  —  2/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb19_28.edf  (0min)
#     Onset :     5.0 min  (00:04:59)
#     Offset:     6.3 min  (00:06:17)  dur=1.3min
#     Pré-ictal máx disp: 5.0 min
#     Motivo     : onset=5.0min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb19_29.edf  (0min)
#     Onset :    49.4 min  (00:49:24)
#     Offset:    50.7 min  (00:50:41)  dur=1.3min
#     Pré-ictal máx disp: 49.4 min  →  reservado [9.4 – 49.4min]
#     Interictal : dedicado  |  arquivo: chb19_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb19_30.edf  (0min)
#     Onset :    52.6 min  (00:52:39)
#     Offset:    54.0 min  (00:54:00)  dur=1.4min
#     Pré-ictal máx disp: 52.6 min  →  reservado [12.7 – 52.6min]
#     Interictal : dedicado  |  arquivo: chb19_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb21  [dedicado]  —  2/4 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb21_19.edf  (0min)
#     Onset :    21.5 min  (00:21:28)
#     Offset:    22.4 min  (00:22:24)  dur=0.9min
#     Pré-ictal máx disp: 21.5 min
#     Motivo     : onset=21.5min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb21_20.edf  (0min)
#     Onset :    43.8 min  (00:43:47)
#     Offset:    44.6 min  (00:44:37)  dur=0.8min
#     Pré-ictal máx disp: 43.8 min  →  reservado [3.8 – 43.8min]
#     Interictal : dedicado  |  arquivo: chb21_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb21_21.edf  (0min)
#     Onset :    33.4 min  (00:33:23)
#     Offset:    34.7 min  (00:34:44)  dur=1.4min
#     Pré-ictal máx disp: 33.4 min
#     Motivo     : onset=33.4min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#   Crise # 1 | chb21_22.edf  (0min)
#     Onset :    42.5 min  (00:42:33)
#     Offset:    42.8 min  (00:42:45)  dur=0.2min
#     Pré-ictal máx disp: 42.5 min  →  reservado [2.5 – 42.5min]
#     Interictal : dedicado  |  arquivo: chb21_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   CHBMIT / chb22  [dedicado]  —  2/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | chb22_20.edf  (0min)
#     Onset :    56.1 min  (00:56:07)
#     Offset:    57.1 min  (00:57:05)  dur=1.0min
#     Pré-ictal máx disp: 56.1 min  →  reservado [16.1 – 56.1min]
#     Interictal : dedicado  |  arquivo: chb22_01.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | chb22_25.edf  (0min)
#     Onset :    52.3 min  (00:52:19)
#     Offset:    53.5 min  (00:53:33)  dur=1.2min
#     Pré-ictal máx disp: 52.3 min  →  reservado [12.3 – 52.3min]
#     Interictal : dedicado  |  arquivo: chb22_02.edf
#                  [0.0 – 16666.7 min]  (16667min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | chb22_38.edf  (0min)
#     Onset :    21.1 min  (00:21:03)
#     Offset:    22.2 min  (00:22:15)  dur=1.2min
#     Pré-ictal máx disp: 21.1 min
#     Motivo     : onset=21.1min < MAX_PRE=40.0min
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN10  [intra-arquivo]  —  4/10 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn10-1.edf  (0min)
#     Onset :   125.8 min  (02:05:45)
#     Offset:   126.9 min  (02:06:54)  dur=1.1min
#     Pré-ictal máx disp: 125.8 min  →  reservado [85.8 – 125.8min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn10-1.edf
#                  [0.0 – 55.8 min]  (56min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn10-10.edf  (0min)
#     Onset :   132.9 min  (02:12:57)
#     Offset:   133.2 min  (02:13:11)  dur=0.2min
#     Pré-ictal máx disp: 132.9 min  →  reservado [93.0 – 132.9min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn10-10.edf
#                  [0.0 – 63.0 min]  (63min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | pn10-2.edf  (0min)
#     Onset :   130.0 min  (02:09:58)
#     Offset:   130.8 min  (02:10:49)  dur=0.8min
#     Pré-ictal máx disp: 130.0 min  →  reservado [90.0 – 130.0min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn10-2.edf
#                  [0.0 – 60.0 min]  (60min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 1 | pn10-3.edf  (0min)
#     Onset :   130.6 min  (02:10:35)
#     Offset:   131.7 min  (02:11:44)  dur=1.1min
#     Pré-ictal máx disp: 130.6 min  →  reservado [90.6 – 130.6min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn10-3.edf
#                  [0.0 – 60.6 min]  (61min)
#     Status     : ✓ CONTEXTO 4
#   Crise # 1 | pn10-4.5.6.edf  (0min)
#     Onset :    38.5 min  (00:38:29)
#     Offset:    38.6 min  (00:38:34)  dur=0.1min
#     Pré-ictal máx disp: 38.5 min
#     Motivo     : onset=38.5min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | pn10-4.5.6.edf  (0min)
#     Onset :   109.1 min  (01:49:04)
#     Offset:   109.4 min  (01:49:23)  dur=0.3min
#     Pré-ictal máx disp: 40.5 min  →  reservado [69.1 – 109.1min]
#     Motivo     : inter insuf: R1_ultimo_seg=0.0min < 40.0min
#     Status     : ✗ inválido
#   Crise # 3 | pn10-4.5.6.edf  (0min)
#     Onset :   187.1 min  (03:07:05)
#     Offset:   188.0 min  (03:08:02)  dur=0.9min
#     Pré-ictal máx disp: 47.7 min  →  reservado [147.1 – 187.1min]
#     Motivo     : inter insuf: R1_ultimo_seg=0.0min < 40.0min
#     Status     : ✗ inválido
#   Crise # 1 | pn10-7.8.9.edf  (0min)
#     Onset :    45.8 min  (00:45:48)
#     Offset:    46.6 min  (00:46:36)  dur=0.8min
#     Pré-ictal máx disp: 45.8 min
#     Motivo     : onset=45.8min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | pn10-7.8.9.edf  (0min)
#     Onset :    91.0 min  (01:30:59)
#     Offset:    91.3 min  (01:31:17)  dur=0.3min
#     Pré-ictal máx disp: 14.4 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 3 | pn10-7.8.9.edf  (0min)
#     Onset :   215.4 min  (03:35:23)
#     Offset:   215.6 min  (03:35:38)  dur=0.2min
#     Pré-ictal máx disp: 94.1 min  →  reservado [175.4 – 215.4min]
#     Motivo     : inter insuf: R1_ultimo_seg=24.1min < 40.0min
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN09  [intra-arquivo]  —  3/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn09-1.edf  (0min)
#     Onset :   120.8 min  (02:00:49)
#     Offset:   122.2 min  (02:02:09)  dur=1.3min
#     Pré-ictal máx disp: 120.8 min  →  reservado [80.8 – 120.8min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn09-1.edf
#                  [0.0 – 50.8 min]  (51min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn09-2.edf  (0min)
#     Onset :   118.8 min  (01:58:47)
#     Offset:   119.8 min  (01:59:46)  dur=1.0min
#     Pré-ictal máx disp: 118.8 min  →  reservado [78.8 – 118.8min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn09-2.edf
#                  [0.0 – 48.8 min]  (49min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | pn09-3.edf  (0min)
#     Onset :   120.3 min  (02:00:21)
#     Offset:   121.4 min  (02:01:25)  dur=1.1min
#     Pré-ictal máx disp: 120.3 min  →  reservado [80.3 – 120.3min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn09-3.edf
#                  [0.0 – 50.4 min]  (50min)
#     Status     : ✓ CONTEXTO 3
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN13  [intra-arquivo]  —  3/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn13-1.edf  (0min)
#     Onset :   117.7 min  (01:57:42)
#     Offset:   118.5 min  (01:58:30)  dur=0.8min
#     Pré-ictal máx disp: 117.7 min  →  reservado [77.7 – 117.7min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn13-1.edf
#                  [0.0 – 47.7 min]  (48min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn13-2.edf  (0min)
#     Onset :   120.8 min  (02:00:49)
#     Offset:   121.9 min  (02:01:54)  dur=1.1min
#     Pré-ictal máx disp: 120.8 min  →  reservado [80.8 – 120.8min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn13-2.edf
#                  [0.0 – 50.8 min]  (51min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | pn13-3.edf  (0min)
#     Onset :   125.9 min  (02:05:53)
#     Offset:   128.4 min  (02:08:24)  dur=2.5min
#     Pré-ictal máx disp: 125.9 min  →  reservado [85.9 – 125.9min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn13-3.edf
#                  [0.0 – 55.9 min]  (56min)
#     Status     : ✓ CONTEXTO 3
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN14  [intra-arquivo]  —  3/4 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn14-1.edf  (0min)
#     Onset :   121.0 min  (02:01:02)
#     Offset:   121.5 min  (02:01:29)  dur=0.5min
#     Pré-ictal máx disp: 121.0 min  →  reservado [81.0 – 121.0min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn14-1.edf
#                  [0.0 – 51.0 min]  (51min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn14-2.edf  (0min)
#     Onset :   124.7 min  (02:04:39)
#     Offset:   124.8 min  (02:04:51)  dur=0.2min
#     Pré-ictal máx disp: 124.7 min  →  reservado [84.7 – 124.7min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn14-2.edf
#                  [0.0 – 54.6 min]  (55min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | pn14-3.edf  (0min)
#     Onset :   292.3 min  (04:52:20)
#     Offset:   293.0 min  (04:53:01)  dur=0.7min
#     Pré-ictal máx disp: 292.3 min  →  reservado [252.3 – 292.3min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn14-3.edf
#                  [0.0 – 222.3 min]  (222min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 1 | pn14-4.edf  (0min)
#     Onset :    91.0 min  (01:31:03)
#     Offset:    92.4 min  (01:32:26)  dur=1.4min
#     Pré-ictal máx disp: 91.0 min  →  reservado [51.0 – 91.0min]
#     Motivo     : inter insuf: R1_ultimo_seg=21.1min < 40.0min
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN01  [intra-arquivo]  —  2/2 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn01-1.edf  (0min)
#     Onset :   170.3 min  (02:50:18)
#     Offset:   171.2 min  (02:51:12)  dur=0.9min
#     Pré-ictal máx disp: 170.3 min  →  reservado [130.3 – 170.3min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn01-1.edf
#                  [0.0 – 100.3 min]  (100min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 2 | pn01-1.edf  (0min)
#     Onset :   772.5 min  (12:52:33)
#     Offset:   773.8 min  (12:53:47)  dur=1.2min
#     Pré-ictal máx disp: 571.4 min  →  reservado [732.5 – 772.5min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn01-1.edf
#                  [201.2 – 702.5 min]  (501min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN03  [intra-arquivo]  —  2/2 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn03-1.edf  (0min)
#     Onset :   644.5 min  (10:44:33)
#     Offset:   646.4 min  (10:46:24)  dur=1.9min
#     Pré-ictal máx disp: 644.5 min  →  reservado [604.5 – 644.5min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn03-1.edf
#                  [0.0 – 574.5 min]  (574min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn03-2.edf  (0min)
#     Onset :   582.0 min  (09:42:01)
#     Offset:   584.2 min  (09:44:14)  dur=2.2min
#     Pré-ictal máx disp: 582.0 min  →  reservado [542.0 – 582.0min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn03-2.edf
#                  [0.0 – 512.0 min]  (512min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN05  [intra-arquivo]  —  2/3 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn05-2.edf  (0min)
#     Onset :   119.4 min  (01:59:23)
#     Offset:   120.0 min  (01:59:58)  dur=0.6min
#     Pré-ictal máx disp: 119.4 min  →  reservado [79.4 – 119.4min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn05-2.edf
#                  [0.0 – 49.4 min]  (49min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn05-3.edf  (0min)
#     Onset :   113.9 min  (01:53:56)
#     Offset:   114.4 min  (01:54:26)  dur=0.5min
#     Pré-ictal máx disp: 113.9 min  →  reservado [73.9 – 113.9min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn05-3.edf
#                  [0.0 – 43.9 min]  (44min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | pn05-4.edf  (0min)
#     Onset :    60.1 min  (01:00:08)
#     Offset:    60.8 min  (01:00:47)  dur=0.7min
#     Pré-ictal máx disp: 60.1 min
#     Motivo     : onset=60.1min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN16  [intra-arquivo]  —  2/2 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn16-1.edf  (0min)
#     Onset :   119.7 min  (01:59:44)
#     Offset:   121.8 min  (02:01:47)  dur=2.0min
#     Pré-ictal máx disp: 119.7 min  →  reservado [79.7 – 119.7min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn16-1.edf
#                  [0.0 – 49.7 min]  (50min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn16-2.edf  (0min)
#     Onset :   142.9 min  (02:22:54)
#     Offset:   144.7 min  (02:24:41)  dur=1.8min
#     Pré-ictal máx disp: 142.9 min  →  reservado [102.9 – 142.9min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn16-2.edf
#                  [0.0 – 72.9 min]  (73min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   Siena / PN17  [intra-arquivo]  —  2/2 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | pn17-1.edf  (0min)
#     Onset :   140.3 min  (02:20:20)
#     Offset:   141.5 min  (02:21:30)  dur=1.2min
#     Pré-ictal máx disp: 140.3 min  →  reservado [100.3 – 140.3min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn17-1.edf
#                  [0.0 – 70.3 min]  (70min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | pn17-2.edf  (0min)
#     Onset :   128.8 min  (02:08:51)
#     Offset:   130.2 min  (02:10:14)  dur=1.4min
#     Pré-ictal máx disp: 128.8 min  →  reservado [88.8 – 128.8min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: pn17-2.edf
#                  [0.0 – 58.9 min]  (59min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   SeizeIT2 / sub-073  [intra-arquivo]  —  12/75 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-16_eeg.edf  (0min)
#     Onset :    56.1 min  (00:56:09)
#     Offset:    57.2 min  (00:57:14)  dur=1.1min
#     Pré-ictal máx disp: 56.1 min
#     Motivo     : onset=56.1min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-20_eeg.edf  (0min)
#     Onset :     3.9 min  (00:03:53)
#     Offset:     5.2 min  (00:05:15)  dur=1.4min
#     Pré-ictal máx disp: 3.9 min
#     Motivo     : onset=3.9min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-24_eeg.edf  (0min)
#     Onset :   247.0 min  (04:06:58)
#     Offset:   248.4 min  (04:08:24)  dur=1.4min
#     Pré-ictal máx disp: 247.0 min  →  reservado [207.0 – 247.0min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-073_ses-01_task-szMonitoring_run-24_eeg.edf
#                  [0.0 – 177.0 min]  (177min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-26_eeg.edf  (0min)
#     Onset :    43.5 min  (00:43:32)
#     Offset:    45.6 min  (00:45:35)  dur=2.0min
#     Pré-ictal máx disp: 43.5 min
#     Motivo     : onset=43.5min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-27_eeg.edf  (0min)
#     Onset :   307.7 min  (05:07:44)
#     Offset:   309.3 min  (05:09:20)  dur=1.6min
#     Pré-ictal máx disp: 307.7 min  →  reservado [267.7 – 307.7min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-073_ses-01_task-szMonitoring_run-27_eeg.edf
#                  [0.0 – 237.7 min]  (238min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-30_eeg.edf  (0min)
#     Onset :    43.8 min  (00:43:48)
#     Offset:    45.6 min  (00:45:35)  dur=1.8min
#     Pré-ictal máx disp: 43.8 min
#     Motivo     : onset=43.8min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-31_eeg.edf  (0min)
#     Onset :   122.4 min  (02:02:26)
#     Offset:   124.4 min  (02:04:22)  dur=1.9min
#     Pré-ictal máx disp: 122.4 min  →  reservado [82.4 – 122.4min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-073_ses-01_task-szMonitoring_run-31_eeg.edf
#                  [0.0 – 52.4 min]  (52min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-31_eeg.edf  (0min)
#     Onset :   256.3 min  (04:16:18)
#     Offset:   257.5 min  (04:17:29)  dur=1.2min
#     Pré-ictal máx disp: 101.9 min  →  reservado [216.3 – 256.3min]
#     Motivo     : inter insuf: R1_ultimo_seg=31.9min < 40.0min
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-32_eeg.edf  (0min)
#     Onset :   119.1 min  (01:59:04)
#     Offset:   120.8 min  (02:00:51)  dur=1.8min
#     Pré-ictal máx disp: 119.1 min  →  reservado [79.1 – 119.1min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-073_ses-01_task-szMonitoring_run-32_eeg.edf
#                  [0.0 – 49.1 min]  (49min)
#     Status     : ✓ CONTEXTO 4
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-34_eeg.edf  (0min)
#     Onset :   201.7 min  (03:21:44)
#     Offset:   203.5 min  (03:23:28)  dur=1.7min
#     Pré-ictal máx disp: 201.7 min  →  reservado [161.7 – 201.7min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-073_ses-01_task-szMonitoring_run-34_eeg.edf
#                  [0.0 – 131.7 min]  (132min)
#     Status     : ✓ CONTEXTO 5
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-35_eeg.edf  (0min)
#     Onset :   256.2 min  (04:16:11)
#     Offset:   256.5 min  (04:16:32)  dur=0.3min
#     Pré-ictal máx disp: 256.2 min  →  reservado [216.2 – 256.2min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-073_ses-01_task-szMonitoring_run-35_eeg.edf
#                  [0.0 – 186.2 min]  (186min)
#     Status     : ✓ CONTEXTO 6
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-36_eeg.edf  (0min)
#     Onset :   107.4 min  (01:47:23)
#     Offset:   108.5 min  (01:48:30)  dur=1.1min
#     Pré-ictal máx disp: 107.4 min  →  reservado [67.4 – 107.4min]
#     Motivo     : inter insuf: R1_ultimo_seg=37.4min < 40.0min
#     Status     : ✗ inválido
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-36_eeg.edf  (0min)
#     Onset :   220.1 min  (03:40:07)
#     Offset:   221.6 min  (03:41:34)  dur=1.4min
#     Pré-ictal máx disp: 81.6 min  →  reservado [180.1 – 220.1min]
#     Motivo     : inter insuf: R1_ultimo_seg=11.6min < 40.0min
#     Status     : ✗ inválido
#   Crise # 3 | sub-073_ses-01_task-szMonitoring_run-36_eeg.edf  (0min)
#     Onset :   233.8 min  (03:53:48)
#     Offset:   235.7 min  (03:55:39)  dur=1.9min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 4 | sub-073_ses-01_task-szMonitoring_run-36_eeg.edf  (0min)
#     Onset :   299.9 min  (04:59:55)
#     Offset:   301.5 min  (05:01:29)  dur=1.6min
#     Pré-ictal máx disp: 34.3 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-37_eeg.edf  (0min)
#     Onset :    40.8 min  (00:40:49)
#     Offset:    43.2 min  (00:43:13)  dur=2.4min
#     Pré-ictal máx disp: 40.8 min
#     Motivo     : onset=40.8min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-37_eeg.edf  (0min)
#     Onset :    81.8 min  (01:21:50)
#     Offset:    83.6 min  (01:23:36)  dur=1.8min
#     Pré-ictal máx disp: 8.6 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 3 | sub-073_ses-01_task-szMonitoring_run-37_eeg.edf  (0min)
#     Onset :   121.8 min  (02:01:48)
#     Offset:   123.2 min  (02:03:14)  dur=1.4min
#     Pré-ictal máx disp: 8.2 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 4 | sub-073_ses-01_task-szMonitoring_run-37_eeg.edf  (0min)
#     Onset :   201.6 min  (03:21:38)
#     Offset:   203.2 min  (03:23:10)  dur=1.5min
#     Pré-ictal máx disp: 48.4 min  →  reservado [161.6 – 201.6min]
#     Motivo     : inter insuf: R1_ultimo_seg=0.0min < 40.0min
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-38_eeg.edf  (0min)
#     Onset :    49.7 min  (00:49:42)
#     Offset:    51.5 min  (00:51:27)  dur=1.8min
#     Pré-ictal máx disp: 49.7 min
#     Motivo     : onset=49.7min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-38_eeg.edf  (0min)
#     Onset :   100.5 min  (01:40:32)
#     Offset:   102.5 min  (01:42:33)  dur=2.0min
#     Pré-ictal máx disp: 19.1 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-39_eeg.edf  (0min)
#     Onset :     9.0 min  (00:08:59)
#     Offset:    10.6 min  (00:10:33)  dur=1.6min
#     Pré-ictal máx disp: 9.0 min
#     Motivo     : onset=9.0min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-39_eeg.edf  (0min)
#     Onset :    13.0 min  (00:13:02)
#     Offset:    14.6 min  (00:14:34)  dur=1.5min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=13.0min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 3 | sub-073_ses-01_task-szMonitoring_run-39_eeg.edf  (0min)
#     Onset :    91.0 min  (01:30:58)
#     Offset:    92.6 min  (01:32:35)  dur=1.6min
#     Pré-ictal máx disp: 46.4 min  →  reservado [51.0 – 91.0min]
#     Motivo     : inter insuf: R1_ultimo_seg=0.0min < 40.0min
#     Status     : ✗ inválido
#   Crise # 4 | sub-073_ses-01_task-szMonitoring_run-39_eeg.edf  (0min)
#     Onset :   112.5 min  (01:52:31)
#     Offset:   114.4 min  (01:54:26)  dur=1.9min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 5 | sub-073_ses-01_task-szMonitoring_run-39_eeg.edf  (0min)
#     Onset :   170.7 min  (02:50:39)
#     Offset:   173.1 min  (02:53:05)  dur=2.4min
#     Pré-ictal máx disp: 26.2 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 6 | sub-073_ses-01_task-szMonitoring_run-39_eeg.edf  (0min)
#     Onset :   211.3 min  (03:31:17)
#     Offset:   213.2 min  (03:33:15)  dur=2.0min
#     Pré-ictal máx disp: 8.2 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-40_eeg.edf  (0min)
#     Onset :    27.8 min  (00:27:50)
#     Offset:    29.1 min  (00:29:04)  dur=1.2min
#     Pré-ictal máx disp: 27.8 min
#     Motivo     : onset=27.8min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-40_eeg.edf  (0min)
#     Onset :   122.5 min  (02:02:31)
#     Offset:   123.9 min  (02:03:55)  dur=1.4min
#     Pré-ictal máx disp: 63.5 min  →  reservado [82.5 – 122.5min]
#     Motivo     : inter insuf: R1_ultimo_seg=0.0min < 40.0min
#     Status     : ✗ inválido
#   Crise # 3 | sub-073_ses-01_task-szMonitoring_run-40_eeg.edf  (0min)
#     Onset :   165.1 min  (02:45:08)
#     Offset:   166.7 min  (02:46:39)  dur=1.5min
#     Pré-ictal máx disp: 11.2 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 4 | sub-073_ses-01_task-szMonitoring_run-40_eeg.edf  (0min)
#     Onset :   199.7 min  (03:19:42)
#     Offset:   201.3 min  (03:21:21)  dur=1.6min
#     Pré-ictal máx disp: 3.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 5 | sub-073_ses-01_task-szMonitoring_run-40_eeg.edf  (0min)
#     Onset :   245.0 min  (04:04:58)
#     Offset:   246.7 min  (04:06:41)  dur=1.7min
#     Pré-ictal máx disp: 13.6 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-41_eeg.edf  (0min)
#     Onset :     6.5 min  (00:06:29)
#     Offset:     7.5 min  (00:07:31)  dur=1.0min
#     Pré-ictal máx disp: 6.5 min
#     Motivo     : onset=6.5min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-41_eeg.edf  (0min)
#     Onset :    13.0 min  (00:13:01)
#     Offset:    14.2 min  (00:14:10)  dur=1.1min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=13.0min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 3 | sub-073_ses-01_task-szMonitoring_run-41_eeg.edf  (0min)
#     Onset :    19.1 min  (00:19:05)
#     Offset:    20.4 min  (00:20:25)  dur=1.3min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=19.1min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 4 | sub-073_ses-01_task-szMonitoring_run-41_eeg.edf  (0min)
#     Onset :    20.9 min  (00:20:51)
#     Offset:    22.6 min  (00:22:39)  dur=1.8min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=20.9min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 5 | sub-073_ses-01_task-szMonitoring_run-41_eeg.edf  (0min)
#     Onset :    46.8 min  (00:46:46)
#     Offset:    48.6 min  (00:48:37)  dur=1.9min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=46.8min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 6 | sub-073_ses-01_task-szMonitoring_run-41_eeg.edf  (0min)
#     Onset :    70.0 min  (01:09:57)
#     Offset:    71.8 min  (01:11:48)  dur=1.9min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=70.0min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 1 | sub-073_ses-01_task-szMonitoring_run-42_eeg.edf  (0min)
#     Onset :     0.0 min  (00:00:01)
#     Offset:     1.6 min  (00:01:36)  dur=1.6min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : onset=0.0min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | sub-073_ses-01_task-szMonitoring_run-42_eeg.edf  (0min)
#     Onset :    61.0 min  (01:01:01)
#     Offset:    62.5 min  (01:02:33)  dur=1.5min
#     Pré-ictal máx disp: 29.4 min
#     Motivo     : onset=61.0min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 3 | sub-073_ses-01_task-szMonitoring_run-42_eeg.edf  (0min)
#     Onset :   105.7 min  (01:45:42)
#     Offset:   107.2 min  (01:47:12)  dur=1.5min
#     Pré-ictal máx disp: 13.2 min
# ...
#     Pré-ictal máx disp: 168.1 min  →  reservado [128.1 – 168.1min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-111_ses-01_task-szMonitoring_run-06_eeg.edf
#                  [0.0 – 98.1 min]  (98min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 2 | sub-111_ses-01_task-szMonitoring_run-06_eeg.edf  (0min)
#     Onset :   667.2 min  (11:07:10)
#     Offset:   669.1 min  (11:09:04)  dur=1.9min
#     Pré-ictal máx disp: 466.8 min  →  reservado [627.2 – 667.2min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-111_ses-01_task-szMonitoring_run-06_eeg.edf
#                  [200.3 – 597.2 min]  (397min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   SeizeIT2 / sub-117  [intra-arquivo]  —  2/11 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | sub-117_ses-01_task-szMonitoring_run-06_eeg.edf  (0min)
#     Onset :   280.8 min  (04:40:47)
#     Offset:   280.9 min  (04:40:52)  dur=0.1min
#     Pré-ictal máx disp: 280.8 min  →  reservado [240.8 – 280.8min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-117_ses-01_task-szMonitoring_run-06_eeg.edf
#                  [0.0 – 210.8 min]  (211min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 2 | sub-117_ses-01_task-szMonitoring_run-06_eeg.edf  (0min)
#     Onset :   344.8 min  (05:44:50)
#     Offset:   344.9 min  (05:44:57)  dur=0.1min
#     Pré-ictal máx disp: 34.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | sub-117_ses-01_task-szMonitoring_run-07_eeg.edf  (0min)
#     Onset :    61.5 min  (01:01:32)
#     Offset:    61.6 min  (01:01:39)  dur=0.1min
#     Pré-ictal máx disp: 61.5 min
#     Motivo     : onset=61.5min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | sub-117_ses-01_task-szMonitoring_run-07_eeg.edf  (0min)
#     Onset :    82.8 min  (01:22:47)
#     Offset:    82.9 min  (01:22:53)  dur=0.1min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 3 | sub-117_ses-01_task-szMonitoring_run-07_eeg.edf  (0min)
#     Onset :    98.9 min  (01:38:56)
#     Offset:    99.1 min  (01:39:06)  dur=0.2min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 4 | sub-117_ses-01_task-szMonitoring_run-07_eeg.edf  (0min)
#     Onset :   118.7 min  (01:58:44)
#     Offset:   118.8 min  (01:58:51)  dur=0.1min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 5 | sub-117_ses-01_task-szMonitoring_run-07_eeg.edf  (0min)
#     Onset :   136.3 min  (02:16:16)
#     Offset:   136.4 min  (02:16:22)  dur=0.1min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | sub-117_ses-01_task-szMonitoring_run-10_eeg.edf  (0min)
#     Onset :   303.9 min  (05:03:55)
#     Offset:   304.1 min  (05:04:04)  dur=0.1min
#     Pré-ictal máx disp: 303.9 min  →  reservado [263.9 – 303.9min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: sub-117_ses-01_task-szMonitoring_run-10_eeg.edf
#                  [0.0 – 233.9 min]  (234min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 2 | sub-117_ses-01_task-szMonitoring_run-10_eeg.edf  (0min)
#     Onset :   319.8 min  (05:19:47)
#     Offset:   320.0 min  (05:20:01)  dur=0.2min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 3 | sub-117_ses-01_task-szMonitoring_run-10_eeg.edf  (0min)
#     Onset :   344.0 min  (05:44:02)
#     Offset:   344.3 min  (05:44:20)  dur=0.3min
#     Pré-ictal máx disp: 0.0 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | sub-117_ses-01_task-szMonitoring_run-11_eeg.edf  (0min)
#     Onset :    18.5 min  (00:18:32)
#     Offset:    19.0 min  (00:18:58)  dur=0.4min
#     Pré-ictal máx disp: 18.5 min
#     Motivo     : onset=18.5min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   Mendeley / p15  [intra-arquivo]  —  3/5 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | p15_record1.edf  (0min)
#     Onset :   119.3 min  (01:59:18)
#     Offset:   120.1 min  (02:00:08)  dur=0.8min
#     Pré-ictal máx disp: 119.3 min  →  reservado [79.3 – 119.3min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: p15_record1.edf
#                  [0.0 – 49.3 min]  (49min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | p15_record2.edf  (0min)
#     Onset :   119.1 min  (01:59:07)
#     Offset:   119.9 min  (01:59:54)  dur=0.8min
#     Pré-ictal máx disp: 119.1 min  →  reservado [79.1 – 119.1min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: p15_record2.edf
#                  [0.0 – 49.1 min]  (49min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | p15_record3.edf  (0min)
#     Onset :   118.9 min  (01:58:52)
#     Offset:   119.1 min  (01:59:05)  dur=0.2min
#     Pré-ictal máx disp: 118.9 min  →  reservado [78.9 – 118.9min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: p15_record3.edf
#                  [0.0 – 48.9 min]  (49min)
#     Status     : ✓ CONTEXTO 3
#   Crise # 1 | p15_record4.edf  (0min)
#     Onset :    40.5 min  (00:40:31)
#     Offset:    41.5 min  (00:41:27)  dur=0.9min
#     Pré-ictal máx disp: 40.5 min
#     Motivo     : onset=40.5min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | p15_record4.edf  (0min)
#     Onset :   120.6 min  (02:00:34)
#     Offset:   120.9 min  (02:00:54)  dur=0.3min
#     Pré-ictal máx disp: 49.1 min  →  reservado [80.6 – 120.6min]
#     Motivo     : inter insuf: R1_ultimo_seg=0.0min < 40.0min
#     Status     : ✗ inválido
#
# ────────────────────────────────────────────────────────────────────────────────
#   Mendeley / p10  [intra-arquivo]  —  2/2 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | p10_record1.edf  (0min)
#     Onset :   120.0 min  (01:59:59)
#     Offset:   127.4 min  (02:07:24)  dur=7.4min
#     Pré-ictal máx disp: 120.0 min  →  reservado [80.0 – 120.0min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: p10_record1.edf
#                  [0.0 – 50.0 min]  (50min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | p10_record2.edf  (0min)
#     Onset :   120.0 min  (02:00:00)
#     Offset:   125.1 min  (02:05:05)  dur=5.1min
#     Pré-ictal máx disp: 120.0 min  →  reservado [80.0 – 120.0min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: p10_record2.edf
#                  [0.0 – 50.0 min]  (50min)
#     Status     : ✓ CONTEXTO 2
#
# ────────────────────────────────────────────────────────────────────────────────
#   Mendeley / p13  [intra-arquivo]  —  2/6 contextos válidos
# ────────────────────────────────────────────────────────────────────────────────
#   Crise # 1 | p13_record1.edf  (0min)
#     Onset :   119.9 min  (01:59:56)
#     Offset:   120.8 min  (02:00:48)  dur=0.9min
#     Pré-ictal máx disp: 119.9 min  →  reservado [79.9 – 119.9min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: p13_record1.edf
#                  [0.0 – 49.9 min]  (50min)
#     Status     : ✓ CONTEXTO 1
#   Crise # 1 | p13_record2.edf  (0min)
#     Onset :    54.0 min  (00:54:01)
#     Offset:    54.4 min  (00:54:26)  dur=0.4min
#     Pré-ictal máx disp: 54.0 min
#     Motivo     : onset=54.0min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | p13_record2.edf  (0min)
#     Onset :   119.9 min  (01:59:56)
#     Offset:   120.2 min  (02:00:12)  dur=0.3min
#     Pré-ictal máx disp: 35.5 min
#     Motivo     : pre-ictal colide com pos-ictal de crise anterior
#     Status     : ✗ inválido
#   Crise # 1 | p13_record3.edf  (0min)
#     Onset :   120.7 min  (02:00:40)
#     Offset:   121.0 min  (02:00:58)  dur=0.3min
#     Pré-ictal máx disp: 120.7 min  →  reservado [80.7 – 120.7min]
#     Interictal : antes (R1-último-segmento)  |  arquivo: p13_record3.edf
#                  [0.0 – 50.7 min]  (51min)
#     Status     : ✓ CONTEXTO 2
#   Crise # 1 | p13_record4.edf  (0min)
#     Onset :    24.2 min  (00:24:10)
#     Offset:    24.7 min  (00:24:40)  dur=0.5min
#     Pré-ictal máx disp: 24.2 min
#     Motivo     : onset=24.2min < 70.0min (MAX_PRE+GUARD)
#     Status     : ✗ inválido
#   Crise # 2 | p13_record4.edf  (0min)
#     Onset :   110.8 min  (01:50:51)
#     Offset:   111.2 min  (01:51:15)  dur=0.4min
#     Pré-ictal máx disp: 56.2 min  →  reservado [70.8 – 110.8min]
#     Motivo     : inter insuf: R1_ultimo_seg=0.0min < 40.0min
#     Status     : ✗ inválido
#
# ================================================================================
# RESUMO CONSOLIDADO
# ================================================================================
#   Dataset      Paciente     Crises   Ctx val    Selecionável?   Fonte inter
#   --------------------------------------------------------------------------
#   CHBMIT       chb06        10       7          Sim ✓           dedicado
#   CHBMIT       chb10        7        5          Sim ✓           dedicado
#   CHBMIT       chb08        5        4          Sim ✓           dedicado
#   CHBMIT       chb09        4        4          Sim ✓           dedicado
#   CHBMIT       chb23        7        4          Sim ✓           dedicado
#   CHBMIT       chb07        3        3          Sim ✓           dedicado
#   CHBMIT       chb02        3        2          Sim ✓           dedicado
#   CHBMIT       chb04        4        2          Sim ✓           dedicado
#   CHBMIT       chb13        12       2          Sim ✓           dedicado
#   CHBMIT       chb14        8        2          Sim ✓           dedicado
#   CHBMIT       chb17        3        2          Sim ✓           dedicado
#   CHBMIT       chb19        3        2          Sim ✓           dedicado
#   CHBMIT       chb21        4        2          Sim ✓           dedicado
#   CHBMIT       chb22        3        2          Sim ✓           dedicado
#   Siena        PN10         10       4          Sim ✓           intra-arquivo
#   Siena        PN09         3        3          Sim ✓           intra-arquivo
#   Siena        PN13         3        3          Sim ✓           intra-arquivo
#   Siena        PN14         4        3          Sim ✓           intra-arquivo
#   Siena        PN01         2        2          Sim ✓           intra-arquivo
#   Siena        PN03         2        2          Sim ✓           intra-arquivo
#   Siena        PN05         3        2          Sim ✓           intra-arquivo
#   Siena        PN16         2        2          Sim ✓           intra-arquivo
#   Siena        PN17         2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-073      75       12         Sim ✓           intra-arquivo
#   SeizeIT2     sub-039      75       9          Sim ✓           intra-arquivo
#   SeizeIT2     sub-035      55       8          Sim ✓           intra-arquivo
#   SeizeIT2     sub-052      9        8          Sim ✓           intra-arquivo
#   SeizeIT2     sub-056      13       8          Sim ✓           intra-arquivo
#   SeizeIT2     sub-113      10       8          Sim ✓           intra-arquivo
#   SeizeIT2     sub-015      9        7          Sim ✓           intra-arquivo
#   SeizeIT2     sub-047      64       7          Sim ✓           intra-arquivo
#   SeizeIT2     sub-103      15       7          Sim ✓           intra-arquivo
#   SeizeIT2     sub-097      13       6          Sim ✓           intra-arquivo
#   SeizeIT2     sub-002      15       5          Sim ✓           intra-arquivo
#   SeizeIT2     sub-030      7        5          Sim ✓           intra-arquivo
#   SeizeIT2     sub-042      11       5          Sim ✓           intra-arquivo
#   SeizeIT2     sub-060      25       5          Sim ✓           intra-arquivo
#   SeizeIT2     sub-115      7        5          Sim ✓           intra-arquivo
#   SeizeIT2     sub-001      4        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-021      4        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-022      7        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-029      4        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-034      30       4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-051      5        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-072      20       4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-080      8        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-112      7        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-116      7        4          Sim ✓           intra-arquivo
#   SeizeIT2     sub-012      3        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-028      4        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-040      3        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-055      8        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-064      3        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-066      4        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-071      6        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-074      9        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-079      15       3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-082      4        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-101      7        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-114      4        3          Sim ✓           intra-arquivo
#   SeizeIT2     sub-007      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-011      4        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-013      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-014      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-024      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-025      3        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-031      3        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-043      5        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-044      4        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-046      4        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-053      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-059      8        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-062      3        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-063      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-065      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-068      3        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-077      9        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-099      4        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-102      3        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-105      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-108      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-109      37       2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-111      2        2          Sim ✓           intra-arquivo
#   SeizeIT2     sub-117      11       2          Sim ✓           intra-arquivo
#   Mendeley     p15          5        3          Sim ✓           intra-arquivo
#   Mendeley     p10          2        2          Sim ✓           intra-arquivo
#   Mendeley     p13          6        2          Sim ✓           intra-arquivo
#   --------------------------------------------------------------------------
#   TOTAL        24 pac       810      302        87 pac sel
#
# Parâmetros: G=30min  P=40min  I=40min  MIN_CTX=2

# %% [markdown]
# ## 9. Pré-processamento e salvamento dos sinais em .npz
#
# Para cada contexto válido:
# 1. Carrega o segmento EDF (interictal e pré-ictal)
# 2. Aplica filtros: passa-alta 0.5Hz, passa-baixa 40Hz, notch 50/60Hz
# 3. Reamostra para TARGET_SFREQ (256Hz)
# 4. Salva em `data/signals/{dataset}__{pat}__ctx{N}.npz`
#
# Cada `.npz` contém:
# - `inter`: sinal interictal (canais × amostras) em µV
# - `pre`: sinal pré-ictal (canais × amostras) em µV
# - `ch_names`: nomes dos canais EEG selecionados
# - `sfreq`: frequência de amostragem após reamostragem
# - `meta`: dicionário com todos os metadados do contexto

# %%
# ── Parâmetros de pré-processamento ──────────────────────────────────────────
CLIP_UV       = 500.0    # Clipping robusto ±500µV (antes da filtragem)
                         # Protege o filtro IIR de ringing causado por artefactos
                         # de saturação do amplificador (movimento, eletrodo solto)
APPLY_CAR     = True     # Re-referência Common Average Reference (CAR)
                         # Aplicada apenas em montagens referenciais multi-canal
                         # (Siena, Mendeley). CHB-MIT (bipolar) e SeizeIT2 (2ch)
                         # excluídos — CAR em bipolar/2ch não tem sentido.
DATASETS_CAR  = {'Siena', 'Mendeley'}   # datasets que recebem CAR

# NOTA sobre Z-score (normalização por segmento):
# Não aplicada ao sinal bruto — removeria a amplitude absoluta (std, var, RMS)
# que é um biomarcador pré-ictal. A normalização de features é feita no NB4
# via StandardScaler (dentro do LOSO, sem leakage).

def load_and_preprocess(path, tmin_s, tmax_s, apply_car=False):
    '''Carrega trecho do EDF, aplica pré-processamento e retorna (data_uV, ch_names, sfreq).

    Pipeline:
      1. Clipping ±CLIP_UV antes da filtragem (protege filtro IIR de artefactos)
      2. Highpass / Lowpass / Notch
      3. Reamostragem para TARGET_SFREQ
      4. CAR (opcional, apenas montagens referenciais multi-canal)
    '''
    if not HAS_MNE or path is None:
        return None, None, None
    try:
        raw = mne.io.read_raw_edf(str(path), preload=False, verbose=False)
        sf  = raw.info['sfreq']

        # limita ao tamanho real
        tmin_s = max(0.0, float(tmin_s))
        tmax_s = min((raw.n_times - 1) / sf, float(tmax_s))
        if tmax_s <= tmin_s:
            raw.close(); return None, None, None

        # seleciona canais EEG
        non_eeg = {'spo2','hr','ekg','ecg','emg','eog','mk','status',
                   'annot','trig','stim','resp','temp'}
        eeg_idx = [i for i,ch in enumerate(raw.ch_names)
                   if ch.upper().startswith('EEG')]
        if not eeg_idx:
            eeg_idx = [i for i,ch in enumerate(raw.ch_names)
                       if not any(kw in ch.lower() for kw in non_eeg)]
        if not eeg_idx:
            eeg_idx = list(range(len(raw.ch_names)))

        ch_names = [raw.ch_names[i] for i in eeg_idx]

        # recorta e carrega em memoria
        raw_crop = raw.copy().crop(tmin=tmin_s, tmax=tmax_s)
        raw_crop.pick(eeg_idx)
        raw_crop.load_data(verbose=False)

        # ── PASSO 1: Clipping robusto ANTES da filtragem ──────────────────────
        # Artefactos de saturação (spikes de ±mV) distorcem o filtro IIR nas
        # janelas vizinhas via efeito de Gibbs. O clip em Volts equivale a CLIP_UV µV.
        clip_v = CLIP_UV * 1e-6   # converte µV → V (unidade do MNE)
        raw_crop._data = np.clip(raw_crop._data, -clip_v, clip_v)

        # ── PASSO 2: Filtragem ────────────────────────────────────────────────
        raw_crop.filter(l_freq=F_HIGHPASS, h_freq=F_LOWPASS,
                        method='iir', verbose=False)
        raw_crop.notch_filter(freqs=NOTCH_FREQS, verbose=False)

        # ── PASSO 3: Reamostragem ─────────────────────────────────────────────
        if abs(sf - TARGET_SFREQ) > 1:
            raw_crop.resample(TARGET_SFREQ, verbose=False)

        data = raw_crop.get_data() * 1e6  # V → µV
        sfreq_out = raw_crop.info['sfreq']
        raw_crop.close(); raw.close()

        # ── PASSO 4: CAR (Common Average Reference) ───────────────────────────
        # Subtrai a média espacial instantânea de todos os canais.
        # Remove artefactos de modo comum (ruído de alimentação, movimento do
        # cabo) e torna o sinal independente da referência do hardware.
        # Apenas para montagens referenciais com ≥8 canais (Siena, Mendeley).
        # CHB-MIT: montagem bipolar — CAR já está implícita; aplicar novamente
        #          introduziria artefactos.
        # SeizeIT2: apenas 2 canais — CAR daria (ch1-ch2)/2 e (ch2-ch1)/2,
        #           destruindo metade da informação útil.
        if apply_car and data.shape[0] >= 8:
            data -= data.mean(axis=0, keepdims=True)  # (n_ch, n_samp) → spatial mean

        return data, ch_names, sfreq_out
    except Exception as e:
        print(f'    Erro {Path(str(path)).name}: {e}')
        return None, None, None

def save_context_npz(dataset, pat, ctx_id, ctx):
    '''Salva o contexto em .npz pre-processado.'''
    out_path = SIGNAL_DIR / f'{dataset}__{pat}__ctx{ctx_id:03d}.npz'
    if out_path.exists():
        return True, 'ja existe'

    car = dataset in DATASETS_CAR
    inter_data, inter_chs, sfreq = load_and_preprocess(
        ctx['inter_path'], ctx['inter_inicio_s'], ctx['inter_fim_s'],
        apply_car=car)
    pre_data, pre_chs, _ = load_and_preprocess(
        ctx['path'], ctx['pre_inicio_s'], ctx['pre_fim_s'],
        apply_car=car)

    if inter_data is None or pre_data is None:
        return False, 'falha ao carregar EDF'

    # garante mesmos canais
    common = [c for c in inter_chs if c in pre_chs]
    if not common:
        common = inter_chs[:min(len(inter_chs), len(pre_chs))]
    inter_idx = [inter_chs.index(c) for c in common if c in inter_chs]
    pre_idx   = [pre_chs.index(c)   for c in common if c in pre_chs]
    if not inter_idx or not pre_idx:
        return False, 'sem canais em comum'

    np.savez_compressed(
        out_path,
        inter     = inter_data[inter_idx],
        pre       = pre_data[pre_idx],
        ch_names  = np.array(common),
        sfreq     = np.array(sfreq),
        meta      = np.array(json.dumps({
            'dataset': dataset, 'paciente': pat, 'contexto_id': ctx_id,
            'arquivo_crise': ctx['edf'], 'onset_s': ctx['on_s'],
            'offset_s': ctx['off_s'],
            'inter_arquivo': ctx['inter_arquivo'],
            'inter_inicio_s': ctx['inter_inicio_s'],
            'inter_fim_s': ctx['inter_fim_s'],
            'inter_fonte': ctx['inter_fonte'],
            'pre_inicio_s': ctx['pre_inicio_s'],
            'pre_fim_s': ctx['pre_fim_s'],
            'pre_max_disp_s': ctx['pre_max_disp_s'],
            'guard_s': GUARD_S, 'max_pre_s': MAX_PRE_S,
            'target_sfreq': TARGET_SFREQ,
        }))
    )
    return True, out_path.name

print('Funções de pré-processamento definidas.')
# Out:
# Funções de pré-processamento definidas.

# %%
# Salva todos os contextos válidos em .npz
print('Salvando contextos em .npz...\n')
saved = 0; failed = 0; skipped = 0
for dataset, pats in SELECTED.items():
    print(f'--- {dataset} ---')
    for pat in pats:
        if pat not in all_contexts.get(dataset, {}): continue
        ctx_id = 0
        for c in all_contexts[dataset][pat]:
            if not c['valid']: continue
            ctx_id += 1
            ok, msg = save_context_npz(dataset, pat, ctx_id, c)
            if 'ja existe' in msg: skipped += 1
            elif ok: saved += 1; print(f'  {pat} ctx{ctx_id:03d}: {msg}')
            else: failed += 1; print(f'  {pat} ctx{ctx_id:03d}: FALHOU — {msg}')

print(f'\nSalvos: {saved} | Já existiam: {skipped} | Falhas: {failed}')
print(f'Total .npz em {SIGNAL_DIR}: {len(list(SIGNAL_DIR.glob("*.npz")))}')
# Out:
# Salvando contextos em .npz...
#
# --- CHBMIT ---
#   chb06 ctx001: CHBMIT__chb06__ctx001.npz
#   chb06 ctx002: CHBMIT__chb06__ctx002.npz
#   chb06 ctx003: CHBMIT__chb06__ctx003.npz
#   chb06 ctx004: CHBMIT__chb06__ctx004.npz
#   chb06 ctx005: CHBMIT__chb06__ctx005.npz
#   chb06 ctx006: CHBMIT__chb06__ctx006.npz
#   chb06 ctx007: CHBMIT__chb06__ctx007.npz
#   chb10 ctx001: CHBMIT__chb10__ctx001.npz
#   chb10 ctx002: CHBMIT__chb10__ctx002.npz
#   chb10 ctx003: CHBMIT__chb10__ctx003.npz
#   chb10 ctx004: CHBMIT__chb10__ctx004.npz
#   chb10 ctx005: CHBMIT__chb10__ctx005.npz
#   chb08 ctx001: CHBMIT__chb08__ctx001.npz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 12
#      10 if not c['valid']: continue
#      11 ctx_id += 1
# ---> 12 ok, msg = save_context_npz(dataset, pat, ctx_id, c)
#      13 if 'ja existe' in msg: skipped += 1
#      14 elif ok: saved += 1; print(f'  {pat} ctx{ctx_id:03d}: {msg}')
#
# Cell In[10], line 117, in save_context_npz(dataset, pat, ctx_id, ctx)
#     114 if not inter_idx or not pre_idx:
#     115     return False, 'sem canais em comum'
# --> 117 np.savez_compressed(
#     118     out_path,
#     119     inter     = inter_data[inter_idx],
#     120     pre       = pre_data[pre_idx],
#     121     ch_names  = np.array(common),
#     122     sfreq     = np.array(sfreq),
#     123     meta      = np.array(json.dumps({
#     124         'dataset': dataset, 'paciente': pat, 'contexto_id': ctx_id,
#     125         'arquivo_crise': ctx['edf'], 'onset_s': ctx['on_s'],
#     126         'offset_s': ctx['off_s'],
#     127         'inter_arquivo': ctx['inter_arquivo'],
#     128         'inter_inicio_s': ctx['inter_inicio_s'],
#     129         'inter_fim_s': ctx['inter_fim_s'],
#     130         'inter_fonte': ctx['inter_fonte'],
#     131         'pre_inicio_s': ctx['pre_inicio_s'],
#     132         'pre_fim_s': ctx['pre_fim_s'],
#     133         'pre_max_disp_s': ctx['pre_max_disp_s'],
#     134         'guard_s': GUARD_S, 'max_pre_s': MAX_PRE_S,
#     135         'target_sfreq': TARGET_SFREQ,
#     136     }))
#     137 )
#     138 return True, out_path.name
#
# File c:\Users\danil\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_npyio_impl.py:763, in savez_compressed(file, allow_pickle, *args, **kwds)
#     691 @array_function_dispatch(_savez_compressed_dispatcher)
#     692 def savez_compressed(file, *args, allow_pickle=True, **kwds):
#     693     """
#     694     Save several arrays into a single file in compressed ``.npz`` format.
#     695
#    (...)    761
#     762     """
# --> 763     _savez(file, args, kwds, True, allow_pickle=allow_pickle)
#
# File c:\Users\danil\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_npyio_impl.py:796, in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     794         # always force zip64, gh-10776
#     795         with zipf.open(fname, 'w', force_zip64=True) as fid:
# --> 796             format.write_array(fid, val,
#     797                                allow_pickle=allow_pickle,
#     798                                pickle_kwargs=pickle_kwargs)
#     799 finally:
#     800     zipf.close()
#
# File c:\Users\danil\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\format.py:759, in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     755 else:
#     756     for chunk in numpy.nditer(
#     757             array, flags=['external_loop', 'buffered', 'zerosize_ok'],
#     758             buffersize=buffersize, order='C'):
# --> 759         fp.write(chunk.tobytes('C'))
#
# File c:\Users\danil\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py:1250, in _ZipWriteFile.write(self, data)
#    1248 self._crc = crc32(data, self._crc)
#    1249 if self._compressor:
# -> 1250     data = self._compressor.compress(data)
#    1251     self._compress_size += len(data)
#    1252 self._fileobj.write(data)
#
# KeyboardInterrupt:

# %%
def load_eeg_for_plot(edf_path, tmin_s, tmax_s):
    '''Carrega trecho sem filtros para visualizacao rapida (media de canais EEG).'''
    if not HAS_MNE or edf_path is None: return None, None
    try:
        raw = mne.io.read_raw_edf(str(edf_path), preload=False, verbose=False)
        sf  = raw.info['sfreq']
        tmin_s = max(0.0, float(tmin_s))
        tmax_s = min((raw.n_times - 1) / sf, float(tmax_s))
        if tmax_s <= tmin_s: raw.close(); return None, None
        non_eeg = {'spo2','hr','ekg','ecg','emg','eog','mk','status','annot','trig','stim'}
        eeg_idx = [i for i,ch in enumerate(raw.ch_names)
                   if ch.upper().startswith('EEG')] or                   [i for i,ch in enumerate(raw.ch_names)
                   if not any(kw in ch.lower() for kw in non_eeg)]
        data, _ = raw[eeg_idx or list(range(len(raw.ch_names))),
                      int(tmin_s*sf):int(tmax_s*sf)]
        raw.close()
        if data.size == 0: return None, None
        mv = np.max(np.abs(data))
        if mv == 0: return None, None
        if mv < 0.001: data *= 1e6
        elif mv < 1.0: data *= 1e3
        t = np.arange(data.shape[1]) / sf / 60.0
        return t, data.mean(axis=0)
    except Exception as e:
        print(f'    Erro plot {Path(str(edf_path)).name}: {e}')
        return None, None

def plot_context(dataset, pat, ctx, ctx_id):
    is_ded = dataset in ('CHBMIT',)
    on, off = ctx['on_s'], ctx['off_s']
    pre_ini = on - MAX_PRE_S
    guard_ini = pre_ini - GUARD_S
    i_ini, i_fim = ctx['inter_inicio_s'], ctx['inter_fim_s']
    inter_dur = i_fim - i_ini

    # Aviso se onset > duracao real
    if ctx['path'] is not None and HAS_MNE:
        try:
            _r = mne.io.read_raw_edf(str(ctx['path']), preload=False, verbose=False)
            _dur = _r.n_times / _r.info['sfreq']
            _r.close()
            if on > _dur:
                print(f'  AVISO: onset={m(on):.1f}min > duracao real ({_dur/60:.1f}min)')
        except: pass

    print(f'\n' + '='*62)
    print(f'  {dataset}/{pat}  |  Contexto #{ctx_id}  |  {ctx["edf"]}  crise #{ctx["sz_idx"]}')
    print('='*62)
    print(f'  Interictal : {m(inter_dur):.1f}min  [{m(i_ini):.1f}-{m(i_fim):.1f}min]  '
          f'fonte={ctx["inter_fonte"]}  arq={ctx["inter_arquivo"]}')
    print(f'  Pre-ictal  : {m(MAX_PRE_S):.0f}min  [{m(pre_ini):.1f}-{m(on):.1f}min]  '
          f'max_disp={m(ctx["pre_max_disp_s"]):.1f}min')
    print(f'  Ictal      : {m(off-on):.1f}min  onset={m(on):.1f}min  offset={m(off):.1f}min')

    def span(ax, a, b, ws, cor, al, lbl):
        am = (a - ws)/60; bm = (b - ws)/60
        if bm > 0: ax.axvspan(max(am,0), bm, color=cor, alpha=al, label=lbl)

    if is_ded:
        fig, (ax1, ax2) = plt.subplots(2,1, figsize=(14,5),
                                        gridspec_kw={'hspace':0.5})
        t_i, sig_i = load_eeg_for_plot(ctx['inter_path'], i_ini, i_fim)
        if t_i is not None:
            ax1.plot(t_i, sig_i, color='#1D9E75', lw=0.5)
            ax1.set_xlim(t_i[0], t_i[-1])
        else:
            ax1.text(0.5,0.5,'Sinal nao carregado',ha='center',va='center',
                     transform=ax1.transAxes,color='gray')
        ax1.set_title(f'INTERICTAL — {ctx["inter_arquivo"]}  [{m(i_ini):.0f}-{m(i_fim):.0f}min]',
                      fontsize=9)
        ax1.set_xlabel('Tempo (min)'); ax1.set_ylabel('uV')

        ws = max(0.0, guard_ini - 120.0)
        we = off + 120.0
        t_c, sig_c = load_eeg_for_plot(ctx['path'], ws, we)
        if t_c is not None:
            ax2.plot(t_c, sig_c, color='#333', lw=0.5)
            ax2.set_xlim(t_c[0], t_c[-1])
        else:
            ax2.text(0.5,0.5,'Sinal nao carregado',ha='center',va='center',
                     transform=ax2.transAxes,color='gray')
        span(ax2, guard_ini, pre_ini, ws, '#999', 0.20, f'guard {int(GUARD_S//60)}min')
        span(ax2, pre_ini,   on,      ws, '#534AB7', 0.25, f'pre-ictal {int(MAX_PRE_S//60)}min')
        span(ax2, on,        off,     ws, '#D85A30', 0.50, 'ictal')
        ax2.legend(fontsize=7, loc='upper left', framealpha=0.8)
        ax2.set_title(f'CRISE — {ctx["edf"]}  onset={m(on):.1f}min', fontsize=9)
        ax2.set_xlabel('Tempo (min)'); ax2.set_ylabel('uV')
    else:
        ws = max(0.0, min(guard_ini, i_ini) - 60.0)
        we = max(off, i_fim) + 120.0
        fig, ax = plt.subplots(1,1, figsize=(14,4))
        t_c, sig_c = load_eeg_for_plot(ctx['path'], ws, we)
        if t_c is not None:
            ax.plot(t_c, sig_c, color='#333', lw=0.5)
            ax.set_xlim(t_c[0], t_c[-1])
        else:
            ax.text(0.5,0.5,'Sinal nao carregado',ha='center',va='center',
                    transform=ax.transAxes,color='gray')
        span(ax, i_ini,    i_fim,   ws, '#1D9E75', 0.18, f'inter {int(MIN_INTER_S//60)}min')
        span(ax, guard_ini, pre_ini, ws, '#999', 0.18, f'guard {int(GUARD_S//60)}min')
        span(ax, pre_ini,   on,      ws, '#534AB7', 0.22, f'pre-ictal {int(MAX_PRE_S//60)}min')
        span(ax, on,        off,     ws, '#D85A30', 0.40, 'ictal')
        ax.legend(fontsize=7, loc='upper left', framealpha=0.8)
        ax.set_title(f'{dataset}/{pat} | ctx#{ctx_id} | {ctx["edf"]} crise#{ctx["sz_idx"]} '
                     f'({ctx["inter_fonte"]})', fontsize=9)
        ax.set_xlabel('Tempo (min)'); ax.set_ylabel('uV')

    plt.tight_layout(); plt.show()

print('Funções de plot definidas.')

# %%
# ── Plot de todos os contextos válidos ────────────────────────────────────────
DATASETS_TO_PLOT = ['CHBMIT','Siena','SeizeIT2','Mendeley']
MAX_CTX_PER_PAT  = None  # None = todos; ex: 2 para testar rapido

for dataset in DATASETS_TO_PLOT:
    for pat in SELECTED[dataset]:
        if pat not in all_contexts.get(dataset, {}): continue
        ctxs_val = [c for c in all_contexts[dataset][pat] if c['valid']]
        if not ctxs_val: continue
        print(f'\n####### {dataset}/{pat} — {len(ctxs_val)} contextos #######')
        to_plot = ctxs_val if MAX_CTX_PER_PAT is None else ctxs_val[:MAX_CTX_PER_PAT]
        for k, ctx in enumerate(to_plot, 1):
            plot_context(dataset, pat, ctx, k)

# %% [markdown]
# ## 11. Exportação do mapa de contextos para o NB2
#
# Salva `data/mapa_contextos_nb1.json` com os timestamps exatos de cada
# contexto válido. O NB2 lê esse arquivo para estimar a janela pré-ictal
# individual por paciente (PRE_SEC) via PELT + K-Means.

# %%
export = []
for dataset, pats in SELECTED.items():
    for pat in pats:
        if pat not in all_contexts.get(dataset, {}): continue
        ctx_id = 0
        for c in all_contexts[dataset][pat]:
            if not c['valid']: continue
            ctx_id += 1
            # janelas fixas disponiveis: 10, 20, 30, 40min
            janelas = [w*60 for w in (10, 20, 30, 40) if w*60 <= c['pre_max_disp_s']]
            export.append({
                'dataset':       dataset,
                'paciente':      pat,
                'contexto_id':   ctx_id,
                'npz_path':      str(SIGNAL_DIR / f'{dataset}__{pat}__ctx{ctx_id:03d}.npz'),
                'arquivo_crise': c['edf'],
                'onset_s':       c['on_s'],
                'offset_s':      c['off_s'],
                'preictal': {
                    'arquivo':   c['edf'],
                    'inicio_s':  c['pre_inicio_s'],
                    'fim_s':     c['pre_fim_s'],
                    'max_disp_s': c['pre_max_disp_s'],
                    'janelas_fixas_s': janelas,
                },
                'interictal': {
                    'arquivo':   c['inter_arquivo'],
                    'inicio_s':  c['inter_inicio_s'],
                    'fim_s':     c['inter_fim_s'],
                    'duracao_s': c['inter_fim_s'] - c['inter_inicio_s'],
                    'fonte':     c['inter_fonte'],
                },
            })

out_path = ROOT / 'mapa_contextos_nb1.json'
with open(out_path, 'w', encoding='utf-8') as f:
    json.dump(export, f, indent=2, ensure_ascii=False)

print(f'Exportados {len(export)} contextos para: {out_path}')
from collections import Counter
for ds, n in Counter(e['dataset'] for e in export).items():
    n_pat = len(set(e['paciente'] for e in export if e['dataset']==ds))
    print(f'  {ds}: {n} contextos em {n_pat} pacientes')

# Download (Google Colab)
try:
    from google.colab import files
    files.download(str(out_path))
except ImportError:
    print(f'Arquivo salvo em: {out_path.resolve()}')
